# %% [markdown]
# Robot Localization with Python and Particle Filters
# ===================================================

# %% [markdown]
# Import libraries and load map.

# %%
import numpy as np
import cv2
map = cv2.imread("map.png",0)
HEIGHT,WIDTH = map.shape
print(map)
rx,ry,rtheta = (WIDTH/4,HEIGHT/4,0)
# Out:
# [[ 79  80  82 ... 133 148 156]
#  [ 78  79  81 ... 138 156 164]
#  [ 76  77  79 ... 147 170 180]
#  ...
#  [181 181 182 ... 174 172 171]
#  [178 178 178 ... 180 179 178]
#  [177 177 177 ... 183 182 182]]

# %% [markdown]
# Map coordinate system
#
# ![title](images/coords.png)
#
# CAUTION: The terrain height at X,Y coordinates is map(Y,X).

# %% [markdown]
# Read keyboard input.

# %%
STEP = 5
TURN =np.radians(25)
def get_input():
    fwd = 0
    turn =  0
    halt = False
    k = cv2.waitKey(0)
    if k == 82:  # Up arrow
        fwd = STEP
    elif k == 83: # Right arrow
        turn = TURN
    elif k == 81: # Left arrow
        turn = -TURN
    elif k == 27:  # ESC to halt 
        halt = True
    return fwd, turn, halt

# %% [markdown]
# Move the robot, with Gausssian noise.
#
# ![title](images/gaussian.png)

# %%
SIGMA_STEP = 0.5
SIGMA_TURN = np.radians(5)

def move_robot(rx, ry, rtheta, fwd, turn):
    fwd_noisy = np.random.normal(fwd,SIGMA_STEP,1)
    rx += fwd_noisy*np.cos(rtheta)
    ry += fwd_noisy*np.sin(rtheta)
    print("fwd_noisy=",fwd_noisy)
    
    turn_noisy = np.random.normal(turn,SIGMA_TURN,1)
    rtheta += turn_noisy
    print("turn_noisy=",np.degrees(turn_noisy))
    
    return rx, ry, rtheta

# %% [markdown]
# Initialize particle cloud.

# %%
NUM_PARTICLES = 3000
def init():
    particles = np.random.rand(NUM_PARTICLES,3)
    particles *=np.array( (WIDTH,HEIGHT,np.radians(360)))

    return particles

# %% [markdown]
# Move the particles.

# %%
def move_particles(particles, fwd, turn):
    particles[:,0] += fwd * np.cos(particles[:,2])
    particles[:,1] += fwd * np.sin(particles[:,2])
    particles[:,2] += turn

    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    return particles
    return particles

# %% [markdown]
# Get value from robot's sensor.

# %%
SIGMA_SENSOR = 2
def sense(x, y, noisy=False):
    x = int(x)
    y = int(y)
    if noisy:
        return np.random.normal(map[y,x], SIGMA_SENSOR, 1)
    return map[y,x]

# %% [markdown]
# Compute particle weights.

# %%
def compute_weights(particles, robot_sensor):    
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        elevation = sense(particles[i,0],particles[i,1], noisy =False)
        errors[i] = abs(robot_sensor - elevation)
    weights = np.max(errors) - errors
    weights[
    (particles[:,0] ==0) |
    (particles[:,0] == WIDTH-1) |
    (particles[:,1] ==0) |
    (particles[:,1] == HEIGHT-1) 
    ] = 0.0
    
    weights = weights **3
    return weights

# %% [markdown]
# Resample the particles.

# %%
def resample(particles, weights):
    probabilities = weights / np.sum(weights)
    new_index = np.random.choice(
    NUM_PARTICLES,
    size = NUM_PARTICLES,
    p = probabilities
    )
    particles = particles[new_index,:]
    return particles

# %% [markdown]
# Add noise to the particles.

# %%
SIGMA_POS =2
SIGMA_TURN = np.radians(10)

def add_noise(particles):
    noise = np.concatenate(
        (
            np.random.normal(0, SIGMA_POS,(NUM_PARTICLES,1)),
            np.random.normal(0, SIGMA_POS,(NUM_PARTICLES,1)),
            np.random.normal(0, SIGMA_TURN,(NUM_PARTICLES,1)),
        ),
        axis =1 
    )
    particles += noise
    return particles

# %% [markdown]
# Display robot, particles and best guess.

# %%
def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)
    
    # Display particles
    if len(particles) > 0:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap, 
                       (int(particles[i,0]), int(particles[i,1])), 
                       1, 
                       (255,0,0), 
                       1)
        
    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)

# %% [markdown]
# Main routine.

# %%
particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)        
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)
    
cv2.destroyAllWindows()
# Out:
# fwd_noisy= [-0.01315139]
# turn_noisy= [13.97305799]
# fwd_noisy= [0.08903268]
# turn_noisy= [-3.26374068]
# fwd_noisy= [0.40359437]
# turn_noisy= [15.96676427]
# fwd_noisy= [0.03576414]
# turn_noisy= [-3.57282208]
# fwd_noisy= [0.37069046]
# turn_noisy= [10.32142041]
# fwd_noisy= [0.39024975]
# turn_noisy= [-26.89395951]
# fwd_noisy= [-0.94082054]
# turn_noisy= [1.88792135]
# fwd_noisy= [-0.53787225]
# turn_noisy= [14.26263248]
# fwd_noisy= [-0.00629686]
# turn_noisy= [-9.33565894]
# fwd_noisy= [-0.30972713]
# turn_noisy= [4.95824355]
# fwd_noisy= [0.47249301]
# turn_noisy= [8.62684174]
# fwd_noisy= [-0.53258628]
# turn_noisy= [-10.42469598]
# fwd_noisy= [0.24975769]
# turn_noisy= [15.60222069]
# fwd_noisy= [-0.30253481]
# turn_noisy= [-0.5830451]
# fwd_noisy= [0.03835695]
# turn_noisy= [13.17476518]
# fwd_noisy= [-0.00647944]
# turn_noisy= [-19.81685868]
# fwd_noisy= [0.53360688]
# turn_noisy= [-9.73389128]
# fwd_noisy= [0.46143516]
# turn_noisy= [6.90182673]
# fwd_noisy= [-0.62877416]
# turn_noisy= [1.97736472]
# fwd_noisy= [0.39668395]
# turn_noisy= [-18.04118343]
# fwd_noisy= [-0.08329492]
# turn_noisy= [-5.67925405]
# fwd_noisy= [0.7917334]
# turn_noisy= [7.7026161]
# fwd_noisy= [-0.71136157]
# turn_noisy= [-0.12633173]
# fwd_noisy= [0.42078818]
# turn_noisy= [5.33738126]
# fwd_noisy= [0.08944462]
# turn_noisy= [4.12585469]
# fwd_noisy= [0.01455042]
# turn_noisy= [22.74173894]
# fwd_noisy= [0.85011912]
# turn_noisy= [-6.55002552]
# fwd_noisy= [-0.39990674]
# turn_noisy= [-3.3396883]
# fwd_noisy= [-0.23632316]
# turn_noisy= [5.24650671]
# fwd_noisy= [0.54534463]
# turn_noisy= [9.4050966]
# fwd_noisy= [-0.31154618]
# turn_noisy= [-6.08520644]
# fwd_noisy= [-0.25424146]
# turn_noisy= [5.73845222]
# fwd_noisy= [0.01471176]
# turn_noisy= [15.68707433]
# fwd_noisy= [-0.0734036]
# turn_noisy= [-3.68331545]
# fwd_noisy= [1.07914693]
# turn_noisy= [14.73620789]
# fwd_noisy= [0.97479879]
# turn_noisy= [19.08927581]
# fwd_noisy= [-0.31336493]
# turn_noisy= [-21.67402869]
# fwd_noisy= [0.20237491]
# turn_noisy= [-2.08864322]
# fwd_noisy= [0.87878779]
# turn_noisy= [1.45452563]
# fwd_noisy= [0.16658332]
# turn_noisy= [4.03966675]
# fwd_noisy= [-0.28139749]
# turn_noisy= [-8.51573798]
# fwd_noisy= [0.21927887]
# turn_noisy= [8.64069976]
# fwd_noisy= [-0.60932325]
# turn_noisy= [1.7283187]
# fwd_noisy= [-0.19853241]
# turn_noisy= [-4.50226778]
# fwd_noisy= [-0.51924881]
# turn_noisy= [-0.67432096]
# fwd_noisy= [-0.26465308]
# turn_noisy= [-16.23847192]
# fwd_noisy= [0.19338156]
# turn_noisy= [-7.26114763]
# fwd_noisy= [-0.85220217]
# turn_noisy= [3.41706558]
# fwd_noisy= [-0.78930396]
# turn_noisy= [20.32653502]
# fwd_noisy= [0.23391841]
# turn_noisy= [-4.32361622]
# fwd_noisy= [-0.54354489]
# turn_noisy= [3.71017085]
# fwd_noisy= [-0.96107761]
# turn_noisy= [11.10378106]
# fwd_noisy= [-0.66984788]
# turn_noisy= [15.72558527]
# fwd_noisy= [-0.64093726]
# turn_noisy= [-7.22461914]
# fwd_noisy= [-0.55521081]
# turn_noisy= [-7.95864453]
# fwd_noisy= [-1.13782572]
# turn_noisy= [-12.19821177]
# fwd_noisy= [-0.03692307]
# turn_noisy= [13.69011421]
# fwd_noisy= [0.3579748]
# turn_noisy= [6.4174348]
# fwd_noisy= [-0.05311064]
# turn_noisy= [11.57089912]
# fwd_noisy= [-0.39833803]
# turn_noisy= [8.49529994]
# fwd_noisy= [-0.09085683]
# turn_noisy= [0.89314697]
# fwd_noisy= [0.23945083]
# turn_noisy= [-14.21395069]
# fwd_noisy= [-0.31320758]
# turn_noisy= [3.5521937]
# fwd_noisy= [0.3949859]
# turn_noisy= [-17.30091013]
# fwd_noisy= [0.16835419]
# turn_noisy= [2.9946542]
# fwd_noisy= [-0.04701501]
# turn_noisy= [-4.6529228]
# fwd_noisy= [0.5581842]
# turn_noisy= [8.21191766]
# fwd_noisy= [0.06592127]
# turn_noisy= [21.34731638]
# fwd_noisy= [0.27663017]
# turn_noisy= [8.90841697]
# fwd_noisy= [0.48791892]
# turn_noisy= [1.08006425]
# fwd_noisy= [-0.32418651]
# turn_noisy= [11.5718868]
# fwd_noisy= [-0.05224697]
# turn_noisy= [-0.7561245]
# fwd_noisy= [-0.51923327]
# turn_noisy= [-11.19679554]
# fwd_noisy= [0.55466133]
# turn_noisy= [-6.70299393]
# fwd_noisy= [1.0708468]
# turn_noisy= [8.70151096]
# fwd_noisy= [0.62104284]
# turn_noisy= [-6.55470682]
# fwd_noisy= [0.64169796]
# turn_noisy= [-7.91177783]
# fwd_noisy= [-0.21508158]
# turn_noisy= [-14.09498707]
# fwd_noisy= [-0.19793236]
# turn_noisy= [2.72053712]
# fwd_noisy= [0.04101118]
# turn_noisy= [14.72515549]
# fwd_noisy= [-0.0652826]
# turn_noisy= [-3.25206834]
# fwd_noisy= [0.32996294]
# turn_noisy= [3.66665283]
# fwd_noisy= [-0.81499321]
# turn_noisy= [17.03614914]
# fwd_noisy= [0.24233604]
# turn_noisy= [7.02501644]
# fwd_noisy= [0.46548059]
# turn_noisy= [-1.04739611]
# fwd_noisy= [0.22741022]
# turn_noisy= [18.06737359]
# fwd_noisy= [-0.30624361]
# turn_noisy= [-0.64487434]
# fwd_noisy= [0.01534901]
# turn_noisy= [-18.40148377]
# fwd_noisy= [-0.09823511]
# turn_noisy= [-3.73401718]
# fwd_noisy= [0.5693006]
# turn_noisy= [-0.81729225]
# fwd_noisy= [0.20726812]
# turn_noisy= [1.15360098]
# fwd_noisy= [0.17781883]
# turn_noisy= [9.6243155]
# fwd_noisy= [0.65311481]
# turn_noisy= [18.64751223]
# fwd_noisy= [-0.28448798]
# turn_noisy= [-8.53338612]
# fwd_noisy= [0.03190257]
# turn_noisy= [7.86230484]
# fwd_noisy= [-0.65714422]
# turn_noisy= [11.89993742]
# fwd_noisy= [-0.38114533]
# turn_noisy= [-3.94846091]
# fwd_noisy= [-0.36861026]
# turn_noisy= [-4.96571922]
# fwd_noisy= [-0.15785012]
# turn_noisy= [12.59016852]
# fwd_noisy= [-0.42821223]
# turn_noisy= [6.73529286]
# fwd_noisy= [-0.59108999]
# turn_noisy= [5.66014878]
# fwd_noisy= [-0.31564654]
# turn_noisy= [-5.86745426]
# fwd_noisy= [0.52450642]
# turn_noisy= [-8.14966212]
# fwd_noisy= [0.60329619]
# turn_noisy= [-2.35343277]
# fwd_noisy= [-0.57676637]
# turn_noisy= [-7.31087343]
# fwd_noisy= [-0.05793667]
# turn_noisy= [-1.51663107]
# fwd_noisy= [-0.49752194]
# turn_noisy= [-5.84330959]
# fwd_noisy= [0.09390877]
# turn_noisy= [8.62071599]
# fwd_noisy= [0.02600648]
# turn_noisy= [-2.26443573]
# fwd_noisy= [-0.12605961]
# turn_noisy= [28.2447147]
# fwd_noisy= [0.00808907]
# turn_noisy= [0.12087941]
# fwd_noisy= [-0.01631124]
# turn_noisy= [23.42516059]
# fwd_noisy= [1.03318732]
# turn_noisy= [4.92403126]
# fwd_noisy= [-0.89649075]
# turn_noisy= [-13.88038909]
# fwd_noisy= [-0.29567383]
# turn_noisy= [-23.82394152]
# fwd_noisy= [0.20990336]
# turn_noisy= [-1.60046557]
# fwd_noisy= [-0.03130657]
# turn_noisy= [13.86242351]
# fwd_noisy= [-0.57033597]
# turn_noisy= [-7.63706452]
# fwd_noisy= [-0.01424354]
# turn_noisy= [-6.38604549]
# fwd_noisy= [0.07021857]
# turn_noisy= [12.89799266]
# fwd_noisy= [-0.75912146]
# turn_noisy= [-14.61536344]
# fwd_noisy= [-0.02275769]
# turn_noisy= [-9.58701443]
# fwd_noisy= [0.37829874]
# turn_noisy= [1.11754453]
# fwd_noisy= [-0.26000301]
# turn_noisy= [-6.45781935]
# fwd_noisy= [0.08083076]
# turn_noisy= [-4.2964185]
# fwd_noisy= [-0.4483107]
# turn_noisy= [-9.66588342]
# fwd_noisy= [1.07489232]
# turn_noisy= [16.5737254]
# fwd_noisy= [-0.92246619]
# turn_noisy= [-13.27560601]
# fwd_noisy= [-0.0238965]
# turn_noisy= [3.69111437]
# fwd_noisy= [0.04984621]
# turn_noisy= [-1.5340268]
# fwd_noisy= [0.09284763]
# turn_noisy= [1.61807818]
# fwd_noisy= [-0.74900351]
# turn_noisy= [8.12452458]
# fwd_noisy= [-0.2405149]
# turn_noisy= [-14.49481787]
# fwd_noisy= [-0.20010261]
# turn_noisy= [6.64790361]
# fwd_noisy= [0.9632014]
# turn_noisy= [17.32880278]
# fwd_noisy= [-0.03852549]
# turn_noisy= [3.00793363]
# fwd_noisy= [-0.04994907]
# turn_noisy= [-0.86976188]
# fwd_noisy= [0.71941288]
# turn_noisy= [-13.81486664]
# fwd_noisy= [0.75533213]
# turn_noisy= [8.87930567]
# fwd_noisy= [0.25444677]
# turn_noisy= [-3.3325355]
# fwd_noisy= [0.24567506]
# turn_noisy= [-1.42455094]
# fwd_noisy= [-0.14341767]
# turn_noisy= [-3.31711686]
# fwd_noisy= [-0.36820883]
# turn_noisy= [0.00916754]
# fwd_noisy= [-0.45221771]
# turn_noisy= [14.88305832]
# fwd_noisy= [-0.5725186]
# turn_noisy= [5.22081482]
# fwd_noisy= [-0.00272789]
# turn_noisy= [-17.68319251]
# fwd_noisy= [0.20337177]
# turn_noisy= [-7.18544151]
# fwd_noisy= [-0.54500897]
# turn_noisy= [2.80671751]
# fwd_noisy= [-0.11552073]
# turn_noisy= [1.37154058]
# fwd_noisy= [0.03292845]
# turn_noisy= [-4.31325852]
# fwd_noisy= [-0.1426086]
# turn_noisy= [5.84939281]
# fwd_noisy= [-0.09446953]
# turn_noisy= [0.24147282]
# fwd_noisy= [-0.99474145]
# turn_noisy= [-11.70069326]
# fwd_noisy= [-0.29243038]
# turn_noisy= [7.40985765]
# fwd_noisy= [0.44870931]
# turn_noisy= [-7.9733841]
# fwd_noisy= [0.16481053]
# turn_noisy= [-20.47107456]
# fwd_noisy= [0.54414478]
# turn_noisy= [9.84273682]
# fwd_noisy= [0.30094277]
# turn_noisy= [18.53544947]
# fwd_noisy= [0.6671912]
# turn_noisy= [9.23883513]
# fwd_noisy= [0.38608142]
# turn_noisy= [1.24858439]
# fwd_noisy= [-0.22128194]
# turn_noisy= [6.33230198]
# fwd_noisy= [-0.20945791]
# turn_noisy= [15.17942135]
# fwd_noisy= [-0.17989772]
# turn_noisy= [-16.29758308]
# fwd_noisy= [-0.50127823]
# turn_noisy= [-11.17382246]
# fwd_noisy= [-0.20686997]
# turn_noisy= [9.80926208]
# fwd_noisy= [0.37643573]
# turn_noisy= [-7.4318133]
# fwd_noisy= [-0.06956966]
# turn_noisy= [-8.10197653]
# fwd_noisy= [-0.42015946]
# turn_noisy= [-2.40334433]
# fwd_noisy= [-0.63256389]
# turn_noisy= [-4.99920266]
# fwd_noisy= [0.20560026]
# turn_noisy= [7.56781093]
# fwd_noisy= [-1.06494902]
# turn_noisy= [8.11674723]
# fwd_noisy= [-0.35523845]
# turn_noisy= [18.24385774]
# fwd_noisy= [0.00026131]
# turn_noisy= [6.35431347]
# fwd_noisy= [-0.36608526]
# turn_noisy= [1.2674704]
# fwd_noisy= [-0.84169859]
# turn_noisy= [-11.07276852]
# fwd_noisy= [-0.10802744]
# turn_noisy= [8.54488537]
# fwd_noisy= [0.01510611]
# turn_noisy= [0.50442842]
# fwd_noisy= [-0.6470747]
# turn_noisy= [-5.9088293]
# fwd_noisy= [-0.35708871]
# turn_noisy= [10.07477676]
# fwd_noisy= [-0.13245172]
# turn_noisy= [1.33366615]
# fwd_noisy= [-0.07151097]
# turn_noisy= [10.6427714]
# fwd_noisy= [-0.12310955]
# turn_noisy= [-11.96108283]
# fwd_noisy= [-0.03208743]
# turn_noisy= [-9.52174828]
# fwd_noisy= [-0.06557518]
# turn_noisy= [-0.79509612]
# fwd_noisy= [-0.11545456]
# turn_noisy= [-12.6047947]
# fwd_noisy= [-0.26708627]
# turn_noisy= [-8.75251339]
# fwd_noisy= [0.20672719]
# turn_noisy= [19.63642992]
# fwd_noisy= [-0.20604952]
# turn_noisy= [-4.62012116]
# fwd_noisy= [0.08982833]
# turn_noisy= [12.0344276]
# fwd_noisy= [-1.02070782]
# turn_noisy= [5.66224848]
# fwd_noisy= [0.52775797]
# turn_noisy= [5.42117295]
# fwd_noisy= [-0.57430911]
# turn_noisy= [-1.92574154]
# fwd_noisy= [0.02480422]
# turn_noisy= [9.24648154]
# fwd_noisy= [-0.19365435]
# turn_noisy= [10.71330231]
# fwd_noisy= [0.26642353]
# turn_noisy= [-4.77538941]
# fwd_noisy= [0.29793162]
# turn_noisy= [-23.00004349]
# fwd_noisy= [0.85034257]
# turn_noisy= [24.16067425]
# fwd_noisy= [-0.11006184]
# turn_noisy= [-6.13808434]
# fwd_noisy= [-0.04891142]
# turn_noisy= [-0.89248709]
# fwd_noisy= [0.06514061]
# turn_noisy= [1.66477528]
# fwd_noisy= [0.31610224]
# turn_noisy= [14.96778867]
# fwd_noisy= [0.11964737]
# turn_noisy= [1.03017589]
# fwd_noisy= [0.12044464]
# turn_noisy= [4.40665472]
# fwd_noisy= [0.64034375]
# turn_noisy= [4.438903]
# fwd_noisy= [-0.470047]
# turn_noisy= [-1.77527745]
# fwd_noisy= [0.28391472]
# turn_noisy= [4.34187299]
# fwd_noisy= [0.9594]
# turn_noisy= [0.4921371]
# fwd_noisy= [-0.28373778]
# turn_noisy= [-22.45453226]
# fwd_noisy= [0.07729539]
# turn_noisy= [-0.37212102]
# fwd_noisy= [-0.18182781]
# turn_noisy= [8.43725667]
# fwd_noisy= [-0.68172404]
# turn_noisy= [11.21988238]
# fwd_noisy= [0.46330108]
# turn_noisy= [-12.36342612]
# fwd_noisy= [0.03134428]
# turn_noisy= [18.97345929]
# fwd_noisy= [0.10376723]
# turn_noisy= [28.1589032]
# fwd_noisy= [-0.49834461]
# turn_noisy= [5.37767507]
# fwd_noisy= [0.91111984]
# turn_noisy= [18.07388515]
# fwd_noisy= [-0.02936189]
# turn_noisy= [11.93468032]
# fwd_noisy= [0.10264073]
# turn_noisy= [-11.28741362]
# fwd_noisy= [-0.42232169]
# turn_noisy= [11.4377918]
# fwd_noisy= [0.48999506]
# turn_noisy= [15.84207837]
# fwd_noisy= [-0.49804576]
# turn_noisy= [2.57067652]
# fwd_noisy= [-0.38198304]
# turn_noisy= [-8.58144095]
# fwd_noisy= [0.02067403]
# turn_noisy= [8.59496377]
# fwd_noisy= [0.46134398]
# turn_noisy= [-2.83976055]
# fwd_noisy= [-0.35536729]
# turn_noisy= [-0.77891425]
# fwd_noisy= [0.18069804]
# turn_noisy= [3.94771235]
# fwd_noisy= [-0.20388405]
# turn_noisy= [-6.80228401]
# fwd_noisy= [0.45366817]
# turn_noisy= [-12.09296891]
# fwd_noisy= [-0.32144719]
# turn_noisy= [-5.58935242]
# fwd_noisy= [0.36341558]
# turn_noisy= [2.47241825]
# fwd_noisy= [-0.26670001]
# turn_noisy= [6.44554927]
# fwd_noisy= [0.07895838]
# turn_noisy= [-23.37461781]
# fwd_noisy= [-1.22911239]
# turn_noisy= [0.35173076]
# fwd_noisy= [-0.27571016]
# turn_noisy= [-7.55226811]
# fwd_noisy= [-0.66281183]
# turn_noisy= [-5.35548932]
# fwd_noisy= [0.02501476]
# turn_noisy= [-7.41731313]
# fwd_noisy= [0.44975827]
# turn_noisy= [24.82066989]
# fwd_noisy= [-0.54040343]
# turn_noisy= [-7.83034726]
# fwd_noisy= [-0.69116128]
# turn_noisy= [3.17190052]
# fwd_noisy= [-0.11599678]
# turn_noisy= [6.5638152]
# fwd_noisy= [0.23557558]
# turn_noisy= [13.24641372]
# fwd_noisy= [0.18727009]
# turn_noisy= [1.53054064]
# fwd_noisy= [0.25964857]
# turn_noisy= [2.47375703]
# fwd_noisy= [0.04471439]
# turn_noisy= [-4.10541059]
# fwd_noisy= [0.12682176]
# turn_noisy= [16.57075193]
# fwd_noisy= [0.28687742]
# turn_noisy= [-14.52980983]
# fwd_noisy= [-0.08437522]
# turn_noisy= [5.93794498]
# fwd_noisy= [0.12857432]
# turn_noisy= [2.99741073]
# fwd_noisy= [0.11734319]
# turn_noisy= [-6.13319521]
# fwd_noisy= [-0.14056308]
# turn_noisy= [15.69979291]
# fwd_noisy= [0.7425273]
# turn_noisy= [16.69119255]
# fwd_noisy= [-0.39245335]
# turn_noisy= [-3.97606492]
# fwd_noisy= [0.33495797]
# turn_noisy= [-2.11101419]
# fwd_noisy= [-0.30870664]
# turn_noisy= [-3.95164268]
# fwd_noisy= [0.20839018]
# turn_noisy= [4.27558064]
# fwd_noisy= [0.47164475]
# turn_noisy= [-9.50194788]
# fwd_noisy= [0.3650091]
# turn_noisy= [4.13891425]
# fwd_noisy= [0.11107282]
# turn_noisy= [-4.66221503]
# fwd_noisy= [-0.27787373]
# turn_noisy= [2.46459472]
# fwd_noisy= [0.5365616]
# turn_noisy= [-2.99688278]
# fwd_noisy= [0.04124609]
# turn_noisy= [-12.51632003]
# fwd_noisy= [0.08300373]
# turn_noisy= [-0.53208792]
# fwd_noisy= [-0.26770006]
# turn_noisy= [-15.04237864]
# fwd_noisy= [-0.19457278]
# turn_noisy= [-19.31430499]
# fwd_noisy= [-0.01869675]
# turn_noisy= [-0.28111726]
# fwd_noisy= [-0.58932509]
# turn_noisy= [7.86548584]
# fwd_noisy= [0.0155259]
# turn_noisy= [-7.84910959]
# fwd_noisy= [0.19236256]
# turn_noisy= [-13.0552347]
# fwd_noisy= [-0.11455497]
# turn_noisy= [3.17727086]
# fwd_noisy= [-0.37832944]
# turn_noisy= [2.29469664]
# fwd_noisy= [-0.35071845]
# turn_noisy= [9.97853206]
# fwd_noisy= [0.27205351]
# turn_noisy= [2.9634413]
# fwd_noisy= [0.219351]
# turn_noisy= [-13.9675098]
# fwd_noisy= [-0.51616341]
# turn_noisy= [-9.30627238]
# fwd_noisy= [0.52691064]
# turn_noisy= [13.64783245]
# fwd_noisy= [0.03815672]
# turn_noisy= [-0.58416111]
# fwd_noisy= [0.13612455]
# turn_noisy= [-13.5651644]
# fwd_noisy= [0.45183168]
# turn_noisy= [0.37227652]
# fwd_noisy= [-0.17827756]
# turn_noisy= [-11.5503586]
# fwd_noisy= [-0.29183169]
# turn_noisy= [2.88312458]
# fwd_noisy= [0.50448109]
# turn_noisy= [3.66810818]
# fwd_noisy= [-0.46321098]
# turn_noisy= [3.18159293]
# fwd_noisy= [0.33080537]
# turn_noisy= [-3.95820921]
# fwd_noisy= [0.22799994]
# turn_noisy= [-1.27020225]
# fwd_noisy= [-0.2497307]
# turn_noisy= [-14.48140302]
# fwd_noisy= [0.9738009]
# turn_noisy= [-7.33853502]
# fwd_noisy= [-0.49667089]
# turn_noisy= [0.75317544]
# fwd_noisy= [0.21168028]
# turn_noisy= [7.56300066]
# fwd_noisy= [0.37782805]
# turn_noisy= [1.14862591]
# fwd_noisy= [0.43473175]
# turn_noisy= [-6.17387689]
# fwd_noisy= [0.31275196]
# turn_noisy= [3.73569133]
# fwd_noisy= [0.2627308]
# turn_noisy= [-5.11318005]
# fwd_noisy= [-0.02229048]
# turn_noisy= [-15.92966143]
# fwd_noisy= [-0.81780927]
# turn_noisy= [7.55028776]
# fwd_noisy= [-0.4421232]
# turn_noisy= [1.05307531]
# fwd_noisy= [-0.71806436]
# turn_noisy= [4.96577845]
# fwd_noisy= [-0.07954447]
# turn_noisy= [15.12283723]
# fwd_noisy= [0.44591867]
# turn_noisy= [-3.35358602]
# fwd_noisy= [-0.48810001]
# turn_noisy= [14.48124736]
# fwd_noisy= [-0.70123878]
# turn_noisy= [3.75168637]
# fwd_noisy= [1.36712909]
# turn_noisy= [-4.86760502]
# fwd_noisy= [1.21476248]
# turn_noisy= [9.84497687]
# fwd_noisy= [0.02415447]
# turn_noisy= [-5.10910294]
# fwd_noisy= [0.24299922]
# turn_noisy= [0.18979441]
# fwd_noisy= [-0.12432666]
# turn_noisy= [-13.9564605]
# fwd_noisy= [-0.24578616]
# turn_noisy= [4.89361689]
# fwd_noisy= [0.72755211]
# turn_noisy= [-1.52347534]
# fwd_noisy= [-0.72293238]
# turn_noisy= [10.10246092]
# fwd_noisy= [0.40659319]
# turn_noisy= [14.66927291]
# fwd_noisy= [0.58152498]
# turn_noisy= [-7.28860041]
# fwd_noisy= [0.1062743]
# turn_noisy= [14.44264148]
# fwd_noisy= [0.27276194]
# turn_noisy= [-2.72578826]
# fwd_noisy= [-0.26092394]
# turn_noisy= [-12.53005526]
# fwd_noisy= [-0.45468728]
# turn_noisy= [-2.55381686]
# fwd_noisy= [-0.4928813]
# turn_noisy= [5.56411581]
# fwd_noisy= [0.10694325]
# turn_noisy= [-7.92037669]
# fwd_noisy= [0.40830136]
# turn_noisy= [2.64225975]
# fwd_noisy= [-0.50309779]
# turn_noisy= [6.34169748]
# fwd_noisy= [0.09346865]
# turn_noisy= [-13.84881294]
# fwd_noisy= [0.37439944]
# turn_noisy= [6.43362206]
# fwd_noisy= [-0.50289403]
# turn_noisy= [0.58626878]
# fwd_noisy= [0.77370264]
# turn_noisy= [-0.47006838]
# fwd_noisy= [0.57786937]
# turn_noisy= [12.44057201]
# fwd_noisy= [0.29630002]
# turn_noisy= [-0.5184372]
# fwd_noisy= [0.0451417]
# turn_noisy= [-13.33930025]
# fwd_noisy= [0.15553648]
# turn_noisy= [-1.37311596]
# fwd_noisy= [0.0764039]
# turn_noisy= [-0.37916748]
# fwd_noisy= [-0.36688956]
# turn_noisy= [-0.21035876]
# fwd_noisy= [-0.47106844]
# turn_noisy= [4.46441646]
# fwd_noisy= [-0.25595613]
# turn_noisy= [-9.06157263]
# fwd_noisy= [-0.35614585]
# turn_noisy= [-0.24592779]
# fwd_noisy= [0.09313307]
# turn_noisy= [-1.25421329]
# fwd_noisy= [0.02043443]
# turn_noisy= [-9.03406951]
# fwd_noisy= [-0.01866355]
# turn_noisy= [3.2598324]
# fwd_noisy= [-0.69130936]
# turn_noisy= [4.36123539]
# fwd_noisy= [0.3228034]
# turn_noisy= [4.0818209]
# fwd_noisy= [-0.40080417]
# turn_noisy= [3.8505405]
# fwd_noisy= [-0.48817802]
# turn_noisy= [-4.29059515]
# fwd_noisy= [-0.10854204]
# turn_noisy= [-11.9128395]
# fwd_noisy= [0.33418531]
# turn_noisy= [-4.6541318]
# fwd_noisy= [-0.10766023]
# turn_noisy= [2.6479414]
# fwd_noisy= [-1.22116634]
# turn_noisy= [12.95622921]
# fwd_noisy= [-0.37370949]
# turn_noisy= [-4.49662085]
# fwd_noisy= [-0.48390155]
# turn_noisy= [-6.06997868]
# fwd_noisy= [-0.30545023]
# turn_noisy= [-5.01469665]
# fwd_noisy= [-0.63455485]
# turn_noisy= [6.8799834]
# fwd_noisy= [-0.06386093]
# turn_noisy= [26.89869419]
# fwd_noisy= [0.38064682]
# turn_noisy= [12.28992487]
# fwd_noisy= [-0.4209572]
# turn_noisy= [-3.4815519]
# fwd_noisy= [0.60385322]
# turn_noisy= [-0.25763181]
# fwd_noisy= [1.08206666]
# turn_noisy= [9.02089074]
# fwd_noisy= [-1.01995219]
# turn_noisy= [-11.23034883]
# fwd_noisy= [0.70683109]
# turn_noisy= [9.66455061]
# fwd_noisy= [-0.0046875]
# turn_noisy= [3.42482257]
# fwd_noisy= [-0.57297853]
# turn_noisy= [-13.26548401]
# fwd_noisy= [0.57312464]
# turn_noisy= [-5.73327681]
# fwd_noisy= [-0.05098365]
# turn_noisy= [2.06294087]
# fwd_noisy= [1.04493452]
# turn_noisy= [6.0807111]
# fwd_noisy= [-0.35170326]
# turn_noisy= [-13.20657958]
# fwd_noisy= [0.2986275]
# turn_noisy= [-13.26925074]
# fwd_noisy= [0.32007177]
# turn_noisy= [18.25178364]
# fwd_noisy= [0.83538272]
# turn_noisy= [-1.43993968]
# fwd_noisy= [-0.05233207]
# turn_noisy= [-7.66710275]
# fwd_noisy= [0.15363196]
# turn_noisy= [-2.05250106]
# fwd_noisy= [-0.37964262]
# turn_noisy= [-1.02944919]
# fwd_noisy= [-0.41471817]
# turn_noisy= [-11.75910932]
# fwd_noisy= [-0.5176126]
# turn_noisy= [-16.53576003]
# fwd_noisy= [-0.24621139]
# turn_noisy= [5.53095619]
# fwd_noisy= [0.30056613]
# turn_noisy= [4.97773261]
# fwd_noisy= [-0.63914217]
# turn_noisy= [17.18476885]
# fwd_noisy= [0.2183579]
# turn_noisy= [-8.67738368]
# fwd_noisy= [-0.70177411]
# turn_noisy= [4.09346091]
# fwd_noisy= [-0.38734716]
# turn_noisy= [18.96986955]
# fwd_noisy= [0.12163786]
# turn_noisy= [-1.36730417]
# fwd_noisy= [-0.7102655]
# turn_noisy= [8.82468962]
# fwd_noisy= [0.13762684]
# turn_noisy= [-14.76480498]
# fwd_noisy= [0.07451976]
# turn_noisy= [2.12935455]
# fwd_noisy= [0.29524809]
# turn_noisy= [-9.89364812]
# fwd_noisy= [-0.03427591]
# turn_noisy= [7.68622286]
# fwd_noisy= [0.7262172]
# turn_noisy= [-11.49478395]
# fwd_noisy= [0.85101272]
# turn_noisy= [-6.27298968]
# fwd_noisy= [0.3826256]
# turn_noisy= [-5.30122343]
# fwd_noisy= [-0.26770475]
# turn_noisy= [19.46110888]
# fwd_noisy= [0.17470826]
# turn_noisy= [-8.93124585]
# fwd_noisy= [-0.23614298]
# turn_noisy= [-0.24379482]
# fwd_noisy= [-1.06342045]
# turn_noisy= [-13.79893376]
# fwd_noisy= [0.4074487]
# turn_noisy= [16.48669519]
# fwd_noisy= [-0.23225528]
# turn_noisy= [-4.4877665]
# fwd_noisy= [-0.3479041]
# turn_noisy= [1.79797455]
# fwd_noisy= [-0.400802]
# turn_noisy= [-12.19833397]
# fwd_noisy= [-1.01742189]
# turn_noisy= [-13.27301065]
# fwd_noisy= [0.35714462]
# turn_noisy= [-4.41360301]
# fwd_noisy= [0.20372369]
# turn_noisy= [-4.73784406]
# fwd_noisy= [1.10483354]
# turn_noisy= [1.34931034]
# fwd_noisy= [-0.0276322]
# turn_noisy= [-1.31529125]
# fwd_noisy= [-0.0770083]
# turn_noisy= [-0.21821594]
# fwd_noisy= [-0.42876814]
# turn_noisy= [-4.22318699]
# fwd_noisy= [-0.06335422]
# turn_noisy= [-3.11411261]
# fwd_noisy= [-0.05585606]
# turn_noisy= [12.02623772]
# fwd_noisy= [-0.0443846]
# turn_noisy= [7.85981731]
# fwd_noisy= [0.65273513]
# turn_noisy= [-0.3104932]
# fwd_noisy= [-0.47680887]
# turn_noisy= [1.71402908]
# fwd_noisy= [0.36016011]
# turn_noisy= [0.46949456]
# fwd_noisy= [0.03599328]
# turn_noisy= [-6.26449613]
# fwd_noisy= [-0.35559287]
# turn_noisy= [-11.92085833]
# fwd_noisy= [-0.57794328]
# turn_noisy= [11.87040752]
# fwd_noisy= [-1.82447112]
# turn_noisy= [13.2797326]
# fwd_noisy= [0.04547764]
# turn_noisy= [-13.62321355]
# fwd_noisy= [0.47392606]
# turn_noisy= [-10.50696075]
# fwd_noisy= [-0.48402605]
# turn_noisy= [4.75352331]
# fwd_noisy= [0.73684615]
# turn_noisy= [11.07022796]
# fwd_noisy= [-0.0180867]
# turn_noisy= [1.27133858]
# fwd_noisy= [-0.38311447]
# turn_noisy= [-4.93855289]
# fwd_noisy= [0.79403536]
# turn_noisy= [-9.68351793]
# fwd_noisy= [-0.33801579]
# turn_noisy= [-2.36028098]
# fwd_noisy= [0.249305]
# turn_noisy= [1.77826073]
# fwd_noisy= [0.10227722]
# turn_noisy= [-16.04665282]
# fwd_noisy= [0.85355829]
# turn_noisy= [-6.88055226]
# fwd_noisy= [0.18114303]
# turn_noisy= [-2.40109801]
# fwd_noisy= [-1.073655]
# turn_noisy= [17.09517431]
# fwd_noisy= [-0.37620914]
# turn_noisy= [-12.06565454]
# fwd_noisy= [0.400316]
# turn_noisy= [-5.78801414]
# fwd_noisy= [-1.05913549]
# turn_noisy= [-8.71263735]
# fwd_noisy= [0.2236175]
# turn_noisy= [12.76732213]
# fwd_noisy= [0.77800108]
# turn_noisy= [-8.96882746]
# fwd_noisy= [-0.35590968]
# turn_noisy= [3.48246451]
# fwd_noisy= [-0.07855066]
# turn_noisy= [16.39844386]
# fwd_noisy= [0.74242416]
# turn_noisy= [7.78612275]
# fwd_noisy= [0.37871931]
# turn_noisy= [-3.70302476]
# fwd_noisy= [0.09761805]
# turn_noisy= [-9.93152986]
# fwd_noisy= [0.56196914]
# turn_noisy= [-3.167312]
# fwd_noisy= [-0.25398554]
# turn_noisy= [-3.04165338]
# fwd_noisy= [0.27465017]
# turn_noisy= [2.7440167]
# fwd_noisy= [0.10479286]
# turn_noisy= [-0.65101252]
# fwd_noisy= [-0.09145983]
# turn_noisy= [-23.63402791]
# fwd_noisy= [0.81201302]
# turn_noisy= [3.46509823]
# fwd_noisy= [-0.9552805]
# turn_noisy= [-3.92166003]
# fwd_noisy= [-0.31413964]
# turn_noisy= [-5.84858864]
# fwd_noisy= [-0.33968345]
# turn_noisy= [5.00911684]
# fwd_noisy= [-0.01758388]
# turn_noisy= [-14.26448613]
# fwd_noisy= [-0.07826282]
# turn_noisy= [1.59515054]
# fwd_noisy= [-0.54477713]
# turn_noisy= [-6.3119358]
# fwd_noisy= [-0.02641863]
# turn_noisy= [-3.9248228]
# fwd_noisy= [-0.69191673]
# turn_noisy= [13.63443455]
# fwd_noisy= [0.11272952]
# turn_noisy= [-4.1482482]
# fwd_noisy= [0.31299022]
# turn_noisy= [16.52047318]
# fwd_noisy= [0.0162768]
# turn_noisy= [-4.31358264]
# fwd_noisy= [0.32571019]
# turn_noisy= [-14.67466396]
# fwd_noisy= [0.39716025]
# turn_noisy= [-4.47745955]
# fwd_noisy= [0.23542295]
# turn_noisy= [-8.48019975]
# fwd_noisy= [0.89730837]
# turn_noisy= [11.47948136]
# fwd_noisy= [-0.68032003]
# turn_noisy= [0.97656522]
# fwd_noisy= [-0.30766624]
# turn_noisy= [9.16452074]
# fwd_noisy= [-0.51890774]
# turn_noisy= [3.39431066]
# fwd_noisy= [0.43951623]
# turn_noisy= [9.54417814]
# fwd_noisy= [0.16122775]
# turn_noisy= [4.79014483]
# fwd_noisy= [-0.29055133]
# turn_noisy= [0.59477028]
# fwd_noisy= [0.21941796]
# turn_noisy= [-1.41532063]
# fwd_noisy= [-0.61237537]
# turn_noisy= [-4.44444957]
# fwd_noisy= [-0.02782006]
# turn_noisy= [7.07111034]
# fwd_noisy= [-1.33581083]
# turn_noisy= [-2.8160892]
# fwd_noisy= [-1.14396457]
# turn_noisy= [8.44184411]
# fwd_noisy= [-0.5402751]
# turn_noisy= [-8.04785843]
# fwd_noisy= [-0.91089543]
# turn_noisy= [-10.70667313]
# fwd_noisy= [-0.11005201]
# turn_noisy= [-0.97217842]
# fwd_noisy= [-0.10187766]
# turn_noisy= [3.75611327]
# fwd_noisy= [0.18022455]
# turn_noisy= [-3.46907668]
# fwd_noisy= [-0.2925859]
# turn_noisy= [0.51264316]
# fwd_noisy= [-0.64547413]
# turn_noisy= [-12.25404595]
# fwd_noisy= [-0.03597593]
# turn_noisy= [-18.26331503]
# fwd_noisy= [-0.13737123]
# turn_noisy= [-13.27279727]
# fwd_noisy= [0.4892381]
# turn_noisy= [-4.31812571]
# fwd_noisy= [0.41199673]
# turn_noisy= [17.36845113]
# fwd_noisy= [0.30538101]
# turn_noisy= [-10.04785878]
# fwd_noisy= [-0.37374406]
# turn_noisy= [3.69903072]
# fwd_noisy= [-0.08921278]
# turn_noisy= [-5.60552707]
# fwd_noisy= [-0.30016603]
# turn_noisy= [-9.59541908]
# fwd_noisy= [-0.02432565]
# turn_noisy= [14.38721176]
# fwd_noisy= [0.13281214]
# turn_noisy= [8.23186154]
# fwd_noisy= [-0.07766473]
# turn_noisy= [-19.76379585]
# fwd_noisy= [-0.19763322]
# turn_noisy= [0.11133637]
# fwd_noisy= [-0.01017468]
# turn_noisy= [9.99986428]
# fwd_noisy= [-0.06058947]
# turn_noisy= [7.99828556]
# fwd_noisy= [0.37559602]
# turn_noisy= [18.79785756]
# fwd_noisy= [-0.0129519]
# turn_noisy= [10.44657493]
# fwd_noisy= [-0.10634346]
# turn_noisy= [-9.74415461]
# fwd_noisy= [-0.07840508]
# turn_noisy= [-12.43188783]
# fwd_noisy= [-0.19289877]
# turn_noisy= [-25.36146245]
# fwd_noisy= [-0.04170991]
# turn_noisy= [-13.55251194]
# fwd_noisy= [-0.99903676]
# turn_noisy= [1.17651635]
# fwd_noisy= [0.6628514]
# turn_noisy= [6.3887101]
# fwd_noisy= [0.9165733]
# turn_noisy= [9.78414498]
# fwd_noisy= [0.1112167]
# turn_noisy= [11.7088866]
# fwd_noisy= [0.14937867]
# turn_noisy= [29.90242419]
# fwd_noisy= [-0.08495898]
# turn_noisy= [18.26834584]
# fwd_noisy= [-0.51425106]
# turn_noisy= [17.95809118]
# fwd_noisy= [-0.29259447]
# turn_noisy= [5.98965944]
# fwd_noisy= [0.14542732]
# turn_noisy= [-0.75540632]
# fwd_noisy= [0.05881624]
# turn_noisy= [6.87433527]
# fwd_noisy= [-0.89079475]
# turn_noisy= [14.23780812]
# fwd_noisy= [-0.4424554]
# turn_noisy= [-8.32338869]
# fwd_noisy= [-0.40771888]
# turn_noisy= [-0.20009973]
# fwd_noisy= [0.33341121]
# turn_noisy= [-18.35238438]
# fwd_noisy= [-0.28709334]
# turn_noisy= [10.71788346]
# fwd_noisy= [0.47265203]
# turn_noisy= [-1.80950328]
# fwd_noisy= [0.90739457]
# turn_noisy= [8.90317773]
# fwd_noisy= [-0.1860959]
# turn_noisy= [-5.52644523]
# fwd_noisy= [-0.18394101]
# turn_noisy= [0.52235438]
# fwd_noisy= [0.15704985]
# turn_noisy= [32.98714552]
# fwd_noisy= [0.11916811]
# turn_noisy= [-1.16168489]
# fwd_noisy= [-0.77498177]
# turn_noisy= [6.24854851]
# fwd_noisy= [0.511968]
# turn_noisy= [-1.61243921]
# fwd_noisy= [0.31520362]
# turn_noisy= [8.6152609]
# fwd_noisy= [-0.04751938]
# turn_noisy= [12.38483451]
# fwd_noisy= [0.67396536]
# turn_noisy= [-4.05726903]
# fwd_noisy= [-0.20785478]
# turn_noisy= [5.1321629]
# fwd_noisy= [-0.05443164]
# turn_noisy= [10.94171924]
# fwd_noisy= [0.56911937]
# turn_noisy= [-15.71971501]
# fwd_noisy= [-0.10405242]
# turn_noisy= [-9.55621542]
# fwd_noisy= [-0.77993377]
# turn_noisy= [-1.18558926]
# fwd_noisy= [0.47821873]
# turn_noisy= [26.52507586]
# fwd_noisy= [-0.07533512]
# turn_noisy= [-4.58397819]
# fwd_noisy= [-0.12316674]
# turn_noisy= [-13.4168215]
# fwd_noisy= [-0.12489169]
# turn_noisy= [-22.9853597]
# fwd_noisy= [0.85871707]
# turn_noisy= [-16.98037258]
# fwd_noisy= [0.21316045]
# turn_noisy= [-4.20928788]
# fwd_noisy= [0.34099183]
# turn_noisy= [-11.06160975]
# fwd_noisy= [-0.13522332]
# turn_noisy= [-7.0526109]
# fwd_noisy= [-0.23190352]
# turn_noisy= [-0.36551401]
# fwd_noisy= [-0.61479436]
# turn_noisy= [11.79862898]
# fwd_noisy= [-0.77072386]
# turn_noisy= [4.44431771]
# fwd_noisy= [-0.58983841]
# turn_noisy= [10.09312693]
# fwd_noisy= [-0.36070913]
# turn_noisy= [4.60213987]
# fwd_noisy= [0.53691721]
# turn_noisy= [-9.75996373]
# fwd_noisy= [-0.02968967]
# turn_noisy= [8.92352358]
# fwd_noisy= [0.36457093]
# turn_noisy= [3.23916742]
# fwd_noisy= [0.21395209]
# turn_noisy= [26.52699161]
# fwd_noisy= [0.71905848]
# turn_noisy= [-0.74583779]
# fwd_noisy= [-0.14765076]
# turn_noisy= [2.25809275]
# fwd_noisy= [0.33238999]
# turn_noisy= [-5.9946484]
# fwd_noisy= [0.70344553]
# turn_noisy= [13.47702577]
# fwd_noisy= [-0.57600101]
# turn_noisy= [21.18949691]
# fwd_noisy= [-0.45638007]
# turn_noisy= [14.09382349]
# fwd_noisy= [0.08338853]
# turn_noisy= [13.1997827]
# fwd_noisy= [0.47620882]
# turn_noisy= [-1.32317109]
# fwd_noisy= [0.13298006]
# turn_noisy= [9.3329584]
# fwd_noisy= [0.67220715]
# turn_noisy= [-7.24833743]
# fwd_noisy= [-0.66531068]
# turn_noisy= [6.57107156]
# fwd_noisy= [-0.68208022]
# turn_noisy= [10.67245901]
# fwd_noisy= [0.26717282]
# turn_noisy= [-9.18841316]
# fwd_noisy= [-0.14293044]
# turn_noisy= [0.56922619]
# fwd_noisy= [-0.15644655]
# turn_noisy= [0.14760374]
# fwd_noisy= [-0.87635094]
# turn_noisy= [-6.62774363]
# fwd_noisy= [0.07820048]
# turn_noisy= [14.91922225]
# fwd_noisy= [-0.31641778]
# turn_noisy= [0.86799976]
# fwd_noisy= [0.00147216]
# turn_noisy= [8.81135782]
# fwd_noisy= [0.27578969]
# turn_noisy= [-15.27802612]
# fwd_noisy= [0.98952195]
# turn_noisy= [2.25864189]
# fwd_noisy= [0.22880675]
# turn_noisy= [11.65553012]
# fwd_noisy= [0.02944416]
# turn_noisy= [-2.6926375]
# fwd_noisy= [-0.06604407]
# turn_noisy= [0.41075924]
# fwd_noisy= [-0.69195676]
# turn_noisy= [3.77746355]
# fwd_noisy= [0.71921087]
# turn_noisy= [13.72293908]
# fwd_noisy= [0.34698727]
# turn_noisy= [2.6759217]
# fwd_noisy= [0.97693511]
# turn_noisy= [1.81341882]
# fwd_noisy= [0.22646146]
# turn_noisy= [4.2662019]
# fwd_noisy= [0.06344223]
# turn_noisy= [19.16675693]
# fwd_noisy= [-0.06952863]
# turn_noisy= [-3.86305417]
# fwd_noisy= [-0.23156955]
# turn_noisy= [13.150574]
# fwd_noisy= [0.27949984]
# turn_noisy= [15.17388396]
# fwd_noisy= [0.4012431]
# turn_noisy= [3.63241077]
# fwd_noisy= [0.03030876]
# turn_noisy= [5.20109324]
# fwd_noisy= [0.59140072]
# turn_noisy= [22.48991162]
# fwd_noisy= [0.00111983]
# turn_noisy= [0.70759008]
# fwd_noisy= [0.40131839]
# turn_noisy= [5.98624394]
# fwd_noisy= [-0.54114332]
# turn_noisy= [18.09314049]
# fwd_noisy= [-0.16691369]
# turn_noisy= [5.76329294]
# fwd_noisy= [-0.47808852]
# turn_noisy= [9.59402063]
# fwd_noisy= [-0.90583752]
# turn_noisy= [-3.9299045]
# fwd_noisy= [-0.67955703]
# turn_noisy= [-4.53661178]
# fwd_noisy= [-0.91349083]
# turn_noisy= [9.00458986]
# fwd_noisy= [0.22286117]
# turn_noisy= [9.97526184]
# fwd_noisy= [0.33425698]
# turn_noisy= [-17.82213273]
# fwd_noisy= [-0.72745808]
# turn_noisy= [21.61197875]
# fwd_noisy= [0.57026275]
# turn_noisy= [-10.61075103]
# fwd_noisy= [-0.53108647]
# turn_noisy= [-8.09281922]
# fwd_noisy= [-1.34499269]
# turn_noisy= [8.33225491]
# fwd_noisy= [-1.20285875]
# turn_noisy= [7.65445455]
# fwd_noisy= [-0.32563394]
# turn_noisy= [-0.60350799]
# fwd_noisy= [-0.48144819]
# turn_noisy= [-29.16783844]
# fwd_noisy= [-0.80472539]
# turn_noisy= [11.72266166]
# fwd_noisy= [0.45478423]
# turn_noisy= [-9.11576936]
# fwd_noisy= [0.15027007]
# turn_noisy= [9.81332166]
# fwd_noisy= [0.13563488]
# turn_noisy= [-9.77530996]
# fwd_noisy= [0.74295964]
# turn_noisy= [-12.02875435]
# fwd_noisy= [1.0099041]
# turn_noisy= [-11.72646402]
# fwd_noisy= [0.25269416]
# turn_noisy= [-0.75060088]
# fwd_noisy= [1.29762662]
# turn_noisy= [12.42472632]
# fwd_noisy= [0.00560087]
# turn_noisy= [1.77786707]
# fwd_noisy= [0.09697022]
# turn_noisy= [-6.14956585]
# fwd_noisy= [0.31842104]
# turn_noisy= [-6.01924915]
# fwd_noisy= [1.27134944]
# turn_noisy= [7.93026018]
# fwd_noisy= [0.28509229]
# turn_noisy= [-2.0554905]
# fwd_noisy= [-0.65547167]
# turn_noisy= [-4.26902842]
# fwd_noisy= [-0.27803849]
# turn_noisy= [3.12463801]
# fwd_noisy= [0.2042223]
# turn_noisy= [-1.03539451]
# fwd_noisy= [0.75137444]
# turn_noisy= [10.57452815]
# fwd_noisy= [0.39365632]
# turn_noisy= [-4.91517648]
# fwd_noisy= [1.17500388]
# turn_noisy= [5.15924267]
# fwd_noisy= [0.65498596]
# turn_noisy= [14.49811128]
# fwd_noisy= [0.32475198]
# turn_noisy= [3.70452566]
# fwd_noisy= [-0.07153085]
# turn_noisy= [4.85640703]
# fwd_noisy= [-0.00311803]
# turn_noisy= [-10.91641965]
# fwd_noisy= [1.08874502]
# turn_noisy= [-9.82384036]
# fwd_noisy= [-0.06719296]
# turn_noisy= [-6.21575685]
# fwd_noisy= [-1.40698776]
# turn_noisy= [-6.01961501]
# fwd_noisy= [0.02841423]
# turn_noisy= [-4.17005128]
# fwd_noisy= [0.04666384]
# turn_noisy= [-1.20378129]
# fwd_noisy= [-0.14889163]
# turn_noisy= [-2.55003816]
# fwd_noisy= [-0.37327725]
# turn_noisy= [24.32657226]
# fwd_noisy= [0.77742854]
# turn_noisy= [4.29212529]
# fwd_noisy= [0.50575394]
# turn_noisy= [-0.88986198]
# fwd_noisy= [0.06599768]
# turn_noisy= [13.86343355]
# fwd_noisy= [0.11932031]
# turn_noisy= [7.5334894]
# fwd_noisy= [-0.0093955]
# turn_noisy= [0.05093469]
# fwd_noisy= [-0.02488147]
# turn_noisy= [-2.26211424]
# fwd_noisy= [0.24615167]
# turn_noisy= [6.60434678]
# fwd_noisy= [-0.43681235]
# turn_noisy= [5.35235921]
# fwd_noisy= [0.93754216]
# turn_noisy= [-8.07276757]
# fwd_noisy= [-0.37072833]
# turn_noisy= [10.61499975]
# fwd_noisy= [1.19444644]
# turn_noisy= [1.21432837]
# fwd_noisy= [-0.54932013]
# turn_noisy= [10.37820196]
# fwd_noisy= [-0.2431198]
# turn_noisy= [6.92927029]
# fwd_noisy= [0.25689758]
# turn_noisy= [1.25993391]
# fwd_noisy= [0.82185256]
# turn_noisy= [-11.54602419]
# fwd_noisy= [-0.33846351]
# turn_noisy= [-9.6972754]
# fwd_noisy= [-0.84218592]
# turn_noisy= [-8.58060648]
# fwd_noisy= [0.23930911]
# turn_noisy= [7.48882316]
# fwd_noisy= [-0.17380688]
# turn_noisy= [6.48307827]
# fwd_noisy= [-0.15625097]
# turn_noisy= [4.89533633]
# fwd_noisy= [-0.00412396]
# turn_noisy= [23.17736507]
# fwd_noisy= [-0.31430505]
# turn_noisy= [24.90727825]
# fwd_noisy= [-0.59793511]
# turn_noisy= [-6.43939624]
# fwd_noisy= [0.04632952]
# turn_noisy= [-2.39232148]
# fwd_noisy= [0.47566178]
# turn_noisy= [0.12641014]
# fwd_noisy= [-0.1212692]
# turn_noisy= [-0.55196716]
# fwd_noisy= [0.83781818]
# turn_noisy= [5.37477557]
# fwd_noisy= [-0.37504569]
# turn_noisy= [0.44749973]
# fwd_noisy= [0.30747201]
# turn_noisy= [4.06398941]
# fwd_noisy= [-0.27040039]
# turn_noisy= [-6.37761276]
# fwd_noisy= [0.48158929]
# turn_noisy= [-14.38562781]
# fwd_noisy= [-0.03797006]
# turn_noisy= [12.80219919]
# fwd_noisy= [0.56673686]
# turn_noisy= [-6.72454629]
# fwd_noisy= [0.1331401]
# turn_noisy= [-9.59467708]
# fwd_noisy= [0.18904364]
# turn_noisy= [-4.46337973]
# fwd_noisy= [0.04288087]
# turn_noisy= [2.60204291]
# fwd_noisy= [-0.17589657]
# turn_noisy= [-4.13448784]
# fwd_noisy= [-0.10861324]
# turn_noisy= [-5.50277392]
# fwd_noisy= [-0.1596784]
# turn_noisy= [-3.32539269]
# fwd_noisy= [0.31387313]
# turn_noisy= [0.44651609]
# fwd_noisy= [0.62308787]
# turn_noisy= [3.16182241]
# fwd_noisy= [-0.37301175]
# turn_noisy= [4.08081262]
# fwd_noisy= [-0.21943734]
# turn_noisy= [-5.45801226]
# fwd_noisy= [-1.06139928]
# turn_noisy= [18.61240549]
# fwd_noisy= [-0.15404038]
# turn_noisy= [8.48556422]
# fwd_noisy= [-0.16130215]
# turn_noisy= [3.98913744]
# fwd_noisy= [0.95061694]
# turn_noisy= [-9.52269815]
# fwd_noisy= [0.21548896]
# turn_noisy= [23.13649399]
# fwd_noisy= [0.00816268]
# turn_noisy= [6.10047248]
# fwd_noisy= [0.48309532]
# turn_noisy= [-5.49709974]
# fwd_noisy= [-0.54206715]
# turn_noisy= [-13.71705739]
# fwd_noisy= [0.47774807]
# turn_noisy= [9.88039512]
# fwd_noisy= [0.47063]
# turn_noisy= [27.84045775]
# fwd_noisy= [-0.24855227]
# turn_noisy= [17.15485559]
# fwd_noisy= [0.56616278]
# turn_noisy= [3.39078129]
# fwd_noisy= [0.00683012]
# turn_noisy= [1.47041684]
# fwd_noisy= [-0.15803217]
# turn_noisy= [1.98526598]
# fwd_noisy= [0.01722188]
# turn_noisy= [3.30485334]
# fwd_noisy= [0.21023386]
# turn_noisy= [-0.68949359]
# fwd_noisy= [0.43199429]
# turn_noisy= [-17.13252823]
# fwd_noisy= [-0.69394551]
# turn_noisy= [-5.94196064]
# fwd_noisy= [-0.12949194]
# turn_noisy= [0.97787859]
# fwd_noisy= [0.04715154]
# turn_noisy= [11.77690019]
# fwd_noisy= [0.36737364]
# turn_noisy= [10.64803428]
# fwd_noisy= [0.28081114]
# turn_noisy= [4.19323358]
# fwd_noisy= [0.11298757]
# turn_noisy= [-9.87023489]
# fwd_noisy= [-0.6684163]
# turn_noisy= [-1.55523327]
# fwd_noisy= [0.37690173]
# turn_noisy= [-4.31067933]
# fwd_noisy= [-0.63977891]
# turn_noisy= [-0.68536451]
# fwd_noisy= [-0.25742247]
# turn_noisy= [-3.82872447]
# fwd_noisy= [0.28697422]
# turn_noisy= [7.05965758]
# fwd_noisy= [0.08308882]
# turn_noisy= [6.57844255]
# fwd_noisy= [-0.46438171]
# turn_noisy= [14.44387262]
# fwd_noisy= [-0.25261676]
# turn_noisy= [-6.85715955]
# fwd_noisy= [0.46969909]
# turn_noisy= [-12.35992806]
# fwd_noisy= [-1.09972575]
# turn_noisy= [-8.43337783]
# fwd_noisy= [-0.26017554]
# turn_noisy= [8.19007407]
# fwd_noisy= [-0.73923729]
# turn_noisy= [1.42882411]
# fwd_noisy= [-0.32389362]
# turn_noisy= [9.98383551]
# fwd_noisy= [0.03361866]
# turn_noisy= [16.50142808]
# fwd_noisy= [-0.45178416]
# turn_noisy= [-11.7732887]
# fwd_noisy= [0.59150547]
# turn_noisy= [-10.40478078]
# fwd_noisy= [0.40119828]
# turn_noisy= [-0.46271597]
# fwd_noisy= [0.3488876]
# turn_noisy= [-7.85564953]
# fwd_noisy= [-1.07111157]
# turn_noisy= [-8.7169727]
# fwd_noisy= [0.17498015]
# turn_noisy= [16.89283122]
# fwd_noisy= [-0.15150953]
# turn_noisy= [13.45838951]
# fwd_noisy= [-0.79668125]
# turn_noisy= [8.7076267]
# fwd_noisy= [0.65300364]
# turn_noisy= [14.73038578]
# fwd_noisy= [0.54474283]
# turn_noisy= [-17.59133451]
# fwd_noisy= [0.12859587]
# turn_noisy= [-10.52121407]
# fwd_noisy= [0.27905254]
# turn_noisy= [-9.75822475]
# fwd_noisy= [0.16190922]
# turn_noisy= [-2.06233037]
# fwd_noisy= [-0.28159885]
# turn_noisy= [-13.31929584]
# fwd_noisy= [-0.54078794]
# turn_noisy= [2.08811274]
# fwd_noisy= [-0.19874121]
# turn_noisy= [0.70423678]
# fwd_noisy= [0.4611812]
# turn_noisy= [-5.33540252]
# fwd_noisy= [0.27161875]
# turn_noisy= [11.73845731]
# fwd_noisy= [-0.27016676]
# turn_noisy= [15.73483708]
# fwd_noisy= [-0.56599657]
# turn_noisy= [-21.56067659]
# fwd_noisy= [0.80509823]
# turn_noisy= [0.62232888]
# fwd_noisy= [-0.60035174]
# turn_noisy= [8.95813974]
# fwd_noisy= [0.21839174]
# turn_noisy= [10.70452931]
# fwd_noisy= [0.00411863]
# turn_noisy= [2.26693281]
# fwd_noisy= [-0.09346071]
# turn_noisy= [-12.11019995]
# fwd_noisy= [0.0517375]
# turn_noisy= [-21.32406767]
# fwd_noisy= [-0.49222241]
# turn_noisy= [0.7466808]
# fwd_noisy= [-0.68449386]
# turn_noisy= [-10.22121995]
# fwd_noisy= [-1.29845142]
# turn_noisy= [6.4321673]
# fwd_noisy= [0.41888159]
# turn_noisy= [2.50612297]
# fwd_noisy= [0.61491535]
# turn_noisy= [2.87482295]
# fwd_noisy= [0.89522748]
# turn_noisy= [9.63503669]
# fwd_noisy= [0.42549236]
# turn_noisy= [3.03437109]
# fwd_noisy= [-0.48547273]
# turn_noisy= [2.51050892]
# fwd_noisy= [-0.35223138]
# turn_noisy= [-4.50307156]
# fwd_noisy= [0.20403201]
# turn_noisy= [-10.95301485]
# fwd_noisy= [0.10293893]
# turn_noisy= [-19.46158229]
# fwd_noisy= [0.06336497]
# turn_noisy= [-0.0575896]
# fwd_noisy= [0.04017708]
# turn_noisy= [8.69356449]
# fwd_noisy= [0.46441944]
# turn_noisy= [3.67051875]
# fwd_noisy= [-0.81598861]
# turn_noisy= [7.88949096]
# fwd_noisy= [0.68901863]
# turn_noisy= [-2.99723237]
# fwd_noisy= [0.49406433]
# turn_noisy= [-0.90349931]
# fwd_noisy= [-0.49502972]
# turn_noisy= [-10.52816667]
# fwd_noisy= [-0.20789075]
# turn_noisy= [2.01189381]
# fwd_noisy= [0.32067757]
# turn_noisy= [-24.02417178]
# fwd_noisy= [-0.42612188]
# turn_noisy= [0.87860055]
# fwd_noisy= [0.28062525]
# turn_noisy= [9.29025517]
# fwd_noisy= [0.04734467]
# turn_noisy= [-3.87966426]
# fwd_noisy= [-0.26979783]
# turn_noisy= [-11.09092677]
# fwd_noisy= [-0.745609]
# turn_noisy= [-2.29222799]
# fwd_noisy= [0.06027916]
# turn_noisy= [-1.69024104]
# fwd_noisy= [0.44715145]
# turn_noisy= [-6.81678942]
# fwd_noisy= [-0.13091346]
# turn_noisy= [3.0008912]
# fwd_noisy= [0.18988325]
# turn_noisy= [2.95971423]
# fwd_noisy= [0.00775135]
# turn_noisy= [14.12329248]
# fwd_noisy= [-0.14126568]
# turn_noisy= [5.3726917]
# fwd_noisy= [-0.50557139]
# turn_noisy= [-1.79662562]
# fwd_noisy= [0.31850372]
# turn_noisy= [-3.82765129]
# fwd_noisy= [0.22977994]
# turn_noisy= [9.75866632]
# fwd_noisy= [0.02708965]
# turn_noisy= [-0.85885648]
# fwd_noisy= [-0.57497833]
# turn_noisy= [-10.14544774]
# fwd_noisy= [0.07168432]
# turn_noisy= [0.31876339]
# fwd_noisy= [-0.15031456]
# turn_noisy= [-7.08040671]
# fwd_noisy= [-0.40286639]
# turn_noisy= [-7.99691287]
# fwd_noisy= [-0.05771714]
# turn_noisy= [0.34812653]
# fwd_noisy= [0.04091738]
# turn_noisy= [-3.24717154]
# fwd_noisy= [0.73753361]
# turn_noisy= [-19.14834573]
# fwd_noisy= [0.17986304]
# turn_noisy= [14.63561578]
# fwd_noisy= [-0.15346097]
# turn_noisy= [8.85595233]
# fwd_noisy= [-0.51684097]
# turn_noisy= [16.24128896]
# fwd_noisy= [0.33850201]
# turn_noisy= [-5.17428493]
# fwd_noisy= [0.19622811]
# turn_noisy= [16.69351476]
# fwd_noisy= [0.32404296]
# turn_noisy= [-5.43671531]
# fwd_noisy= [-0.85009585]
# turn_noisy= [-14.80630024]
# fwd_noisy= [-0.24653005]
# turn_noisy= [-10.63553046]
# fwd_noisy= [-0.80433485]
# turn_noisy= [5.18995443]
# fwd_noisy= [0.38942362]
# turn_noisy= [-3.57256897]
# fwd_noisy= [0.03302389]
# turn_noisy= [-11.82609079]
# fwd_noisy= [-1.05306887]
# turn_noisy= [-12.5964705]
# fwd_noisy= [-0.15873156]
# turn_noisy= [3.24544359]
# fwd_noisy= [0.59160543]
# turn_noisy= [16.84696377]
# fwd_noisy= [-0.08971441]
# turn_noisy= [7.96776255]
# fwd_noisy= [-0.10246736]
# turn_noisy= [4.51851333]
# fwd_noisy= [0.35121879]
# turn_noisy= [9.73127675]
# fwd_noisy= [0.04916998]
# turn_noisy= [10.68380667]
# fwd_noisy= [-0.10431662]
# turn_noisy= [-7.19526555]
# fwd_noisy= [-0.07976653]
# turn_noisy= [8.9525718]
# fwd_noisy= [0.2931921]
# turn_noisy= [-6.26554164]
# fwd_noisy= [-0.03499483]
# turn_noisy= [-14.33447027]
# fwd_noisy= [-0.11893807]
# turn_noisy= [-5.99177161]
# fwd_noisy= [0.72626819]
# turn_noisy= [9.48331133]
# fwd_noisy= [-0.07535475]
# turn_noisy= [-4.64738778]
# fwd_noisy= [-0.35125919]
# turn_noisy= [10.07763222]
# fwd_noisy= [0.48827733]
# turn_noisy= [8.0536855]
# fwd_noisy= [-0.75807619]
# turn_noisy= [-11.46169501]
# fwd_noisy= [0.74911534]
# turn_noisy= [2.41206366]
# fwd_noisy= [-0.07609485]
# turn_noisy= [2.4964387]
# fwd_noisy= [-0.02145212]
# turn_noisy= [-6.17782229]
# fwd_noisy= [-0.37931584]
# turn_noisy= [-5.09689539]
# fwd_noisy= [0.325938]
# turn_noisy= [-6.36768427]
# fwd_noisy= [-0.52768529]
# turn_noisy= [-7.27559333]
# fwd_noisy= [-0.32143664]
# turn_noisy= [0.01877126]
# fwd_noisy= [0.27730585]
# turn_noisy= [8.8503046]
# fwd_noisy= [0.97693687]
# turn_noisy= [13.95445244]
# fwd_noisy= [0.01569074]
# turn_noisy= [3.94405686]
# fwd_noisy= [1.17604109]
# turn_noisy= [-13.57300381]
# fwd_noisy= [0.04486556]
# turn_noisy= [-17.11609178]
# fwd_noisy= [-0.32778002]
# turn_noisy= [-28.23423291]
# fwd_noisy= [-1.19048034]
# turn_noisy= [-8.78824405]
# fwd_noisy= [-0.31277967]
# turn_noisy= [7.72519507]
# fwd_noisy= [-0.05530251]
# turn_noisy= [-4.09737335]
# fwd_noisy= [-0.1794847]
# turn_noisy= [12.79703293]
# fwd_noisy= [-0.72415873]
# turn_noisy= [0.22734636]
# fwd_noisy= [-0.80230757]
# turn_noisy= [12.06454613]
# fwd_noisy= [-0.13151076]
# turn_noisy= [-5.405558]
# fwd_noisy= [0.72454572]
# turn_noisy= [-7.87351955]
# fwd_noisy= [0.4548185]
# turn_noisy= [3.72339409]
# fwd_noisy= [-0.46394555]
# turn_noisy= [-7.93543006]
# fwd_noisy= [0.24812134]
# turn_noisy= [-2.39334414]
# fwd_noisy= [0.01693816]
# turn_noisy= [29.57391882]
# fwd_noisy= [-0.66350616]
# turn_noisy= [-4.41855607]
# fwd_noisy= [-0.20360646]
# turn_noisy= [-11.02077695]
# fwd_noisy= [-0.49736225]
# turn_noisy= [-7.75138699]
# fwd_noisy= [-0.58207406]
# turn_noisy= [12.4984148]
# fwd_noisy= [0.3163076]
# turn_noisy= [1.76529693]
# fwd_noisy= [-0.24610064]
# turn_noisy= [-8.15374953]
# fwd_noisy= [0.81704772]
# turn_noisy= [-9.52589638]
# fwd_noisy= [-0.43094883]
# turn_noisy= [12.75286423]
# fwd_noisy= [0.33428683]
# turn_noisy= [2.93044813]
# fwd_noisy= [-0.63328608]
# turn_noisy= [1.61244371]
# fwd_noisy= [-0.35490744]
# turn_noisy= [7.59734601]
# fwd_noisy= [-0.25918381]
# turn_noisy= [14.80454713]
# fwd_noisy= [0.08710033]
# turn_noisy= [-0.1174899]
# fwd_noisy= [-0.32617776]
# turn_noisy= [22.38608996]
# fwd_noisy= [-0.00246359]
# turn_noisy= [-8.16729674]
# fwd_noisy= [0.00213231]
# turn_noisy= [3.23036394]
# fwd_noisy= [0.13404963]
# turn_noisy= [-4.8953599]
# fwd_noisy= [0.33853673]
# turn_noisy= [9.79413781]
# fwd_noisy= [-0.08567064]
# turn_noisy= [4.52902414]
# fwd_noisy= [0.67676956]
# turn_noisy= [10.94993035]
# fwd_noisy= [-0.44003253]
# turn_noisy= [2.22202727]
# fwd_noisy= [-1.45908506]
# turn_noisy= [-1.41442823]
# fwd_noisy= [-0.28487021]
# turn_noisy= [27.24401583]
# fwd_noisy= [-0.51347357]
# turn_noisy= [-19.79359441]
# fwd_noisy= [0.53999941]
# turn_noisy= [6.94278245]
# fwd_noisy= [-1.0702441]
# turn_noisy= [-20.5027678]
# fwd_noisy= [0.37817346]
# turn_noisy= [8.21802612]
# fwd_noisy= [-0.97514067]
# turn_noisy= [-9.59283292]
# fwd_noisy= [1.14041978]
# turn_noisy= [-2.28950439]
# fwd_noisy= [-0.4803681]
# turn_noisy= [2.94458774]
# fwd_noisy= [0.12974752]
# turn_noisy= [-9.70111061]
# fwd_noisy= [0.25050178]
# turn_noisy= [5.76146742]
# fwd_noisy= [-0.86933179]
# turn_noisy= [10.33910786]
# fwd_noisy= [-0.11134343]
# turn_noisy= [0.723651]
# fwd_noisy= [-0.52184333]
# turn_noisy= [-10.13499594]
# fwd_noisy= [0.10082369]
# turn_noisy= [-3.76517279]
# fwd_noisy= [-0.01746251]
# turn_noisy= [5.98750663]
# fwd_noisy= [0.37877902]
# turn_noisy= [-5.16683929]
# fwd_noisy= [-0.36525133]
# turn_noisy= [-11.79823678]
# fwd_noisy= [0.09841051]
# turn_noisy= [5.00146528]
# fwd_noisy= [-0.52386455]
# turn_noisy= [3.44928584]
# fwd_noisy= [-0.32538476]
# turn_noisy= [1.30352802]
# fwd_noisy= [0.6237519]
# turn_noisy= [18.03528791]
# fwd_noisy= [-0.15358982]
# turn_noisy= [-16.01809826]
# fwd_noisy= [0.77184918]
# turn_noisy= [4.2808052]
# fwd_noisy= [-0.31273652]
# turn_noisy= [-12.571291]
# fwd_noisy= [-0.41283002]
# turn_noisy= [-6.6030321]
# fwd_noisy= [-0.51469771]
# turn_noisy= [13.88948539]
# fwd_noisy= [-0.06687724]
# turn_noisy= [-6.24098164]
# fwd_noisy= [0.07230375]
# turn_noisy= [-4.97493845]
# fwd_noisy= [-0.84754314]
# turn_noisy= [-0.69327724]
# fwd_noisy= [-0.28522383]
# turn_noisy= [-20.26455863]
# fwd_noisy= [0.0923395]
# turn_noisy= [-5.8690825]
# fwd_noisy= [0.61709094]
# turn_noisy= [11.45275816]
# fwd_noisy= [-0.27076953]
# turn_noisy= [-6.81681464]
# fwd_noisy= [0.40187619]
# turn_noisy= [9.28838148]
# fwd_noisy= [-0.45974165]
# turn_noisy= [7.307596]
# fwd_noisy= [0.26974584]
# turn_noisy= [10.37974244]
# fwd_noisy= [-0.62033858]
# turn_noisy= [22.88444549]
# fwd_noisy= [0.62216244]
# turn_noisy= [-4.00463674]
# fwd_noisy= [0.1272956]
# turn_noisy= [-13.49490539]
# fwd_noisy= [0.28270414]
# turn_noisy= [1.98349058]
# fwd_noisy= [-0.13171784]
# turn_noisy= [-11.74877183]
# fwd_noisy= [0.10248052]
# turn_noisy= [31.79522316]
# fwd_noisy= [-1.04573858]
# turn_noisy= [1.79033156]
# fwd_noisy= [0.55472854]
# turn_noisy= [-2.1970019]
# fwd_noisy= [-0.40064927]
# turn_noisy= [9.44506065]
# fwd_noisy= [-0.41580167]
# turn_noisy= [8.58927065]
# fwd_noisy= [-0.41462797]
# turn_noisy= [1.52603719]
# fwd_noisy= [-0.2888233]
# turn_noisy= [-17.26178696]
# fwd_noisy= [-0.17209716]
# turn_noisy= [1.68093606]
# fwd_noisy= [0.11617077]
# turn_noisy= [-8.13135483]
# fwd_noisy= [-0.19951533]
# turn_noisy= [0.20075535]
# fwd_noisy= [0.28654658]
# turn_noisy= [8.87568514]
# fwd_noisy= [-0.33838795]
# turn_noisy= [16.06591219]
# fwd_noisy= [0.07194631]
# turn_noisy= [-1.26104021]
# fwd_noisy= [-0.44686502]
# turn_noisy= [4.08557769]
# fwd_noisy= [-0.48687792]
# turn_noisy= [10.67339963]
# fwd_noisy= [0.18993283]
# turn_noisy= [-15.89998162]
# fwd_noisy= [-0.03200866]
# turn_noisy= [16.16569542]
# fwd_noisy= [-0.49342224]
# turn_noisy= [-0.3184791]
# fwd_noisy= [0.15082819]
# turn_noisy= [3.04177101]
# fwd_noisy= [-0.03583644]
# turn_noisy= [-9.23727647]
# fwd_noisy= [0.54970462]
# turn_noisy= [6.31825809]
# fwd_noisy= [-0.16508862]
# turn_noisy= [4.88981136]
# fwd_noisy= [1.0138853]
# turn_noisy= [-4.46246032]
# fwd_noisy= [-0.37498812]
# turn_noisy= [2.26814786]
# fwd_noisy= [-0.99697822]
# turn_noisy= [-1.36397715]
# fwd_noisy= [0.03424425]
# turn_noisy= [8.3015026]
# fwd_noisy= [-0.10706186]
# turn_noisy= [4.68461619]
# fwd_noisy= [-0.3269909]
# turn_noisy= [7.89198832]
# fwd_noisy= [0.39932442]
# turn_noisy= [0.57160089]
# fwd_noisy= [-0.75941208]
# turn_noisy= [-0.2066836]
# fwd_noisy= [-0.25220518]
# turn_noisy= [0.4152661]
# fwd_noisy= [0.08432212]
# turn_noisy= [13.28283726]
# fwd_noisy= [-0.1930202]
# turn_noisy= [-1.8580626]
# fwd_noisy= [-0.3999613]
# turn_noisy= [-6.96251509]
# fwd_noisy= [0.95867821]
# turn_noisy= [-6.06830565]
# fwd_noisy= [0.85758318]
# turn_noisy= [-3.35601792]
# fwd_noisy= [0.46232897]
# turn_noisy= [-6.24360587]
# fwd_noisy= [0.38430665]
# turn_noisy= [12.87979712]
# fwd_noisy= [-0.83284363]
# turn_noisy= [-0.75773262]
# fwd_noisy= [0.09225937]
# turn_noisy= [16.71284526]
# fwd_noisy= [-0.15269361]
# turn_noisy= [-10.24609859]
# fwd_noisy= [-0.15108547]
# turn_noisy= [11.82134564]
# fwd_noisy= [0.21943473]
# turn_noisy= [6.89472308]
# fwd_noisy= [-0.69427037]
# turn_noisy= [-4.10443264]
# fwd_noisy= [-0.3025603]
# turn_noisy= [-22.74460199]
# fwd_noisy= [0.47679996]
# turn_noisy= [-5.87279248]
# fwd_noisy= [-0.42633076]
# turn_noisy= [0.53329961]
# fwd_noisy= [-0.29158216]
# turn_noisy= [-12.13630195]
# fwd_noisy= [-0.74282916]
# turn_noisy= [-15.16579132]
# fwd_noisy= [0.19591404]
# turn_noisy= [2.98846535]
# fwd_noisy= [0.26481478]
# turn_noisy= [-0.02058211]
# fwd_noisy= [-0.25790012]
# turn_noisy= [2.94969049]
# fwd_noisy= [-0.34728192]
# turn_noisy= [-18.20288612]
# fwd_noisy= [-0.87278185]
# turn_noisy= [-2.66148789]
# fwd_noisy= [0.31983911]
# turn_noisy= [-4.13375363]
# fwd_noisy= [-0.32138271]
# turn_noisy= [-4.11248586]
# fwd_noisy= [-0.35749008]
# turn_noisy= [0.39300265]
# fwd_noisy= [-0.43180758]
# turn_noisy= [-10.42211994]
# fwd_noisy= [-0.36984164]
# turn_noisy= [1.51456336]
# fwd_noisy= [0.68809328]
# turn_noisy= [-5.61187957]
# fwd_noisy= [0.59257508]
# turn_noisy= [-10.64671109]
# fwd_noisy= [-1.64741393]
# turn_noisy= [-5.88203561]
# fwd_noisy= [-0.18554299]
# turn_noisy= [-25.50233364]
# fwd_noisy= [-0.41016154]
# turn_noisy= [-15.38029755]
# fwd_noisy= [0.48308217]
# turn_noisy= [-4.7198235]
# fwd_noisy= [0.03009276]
# turn_noisy= [12.52186287]
# fwd_noisy= [-0.42728629]
# turn_noisy= [1.44837954]
# fwd_noisy= [0.8368756]
# turn_noisy= [11.33774593]
# fwd_noisy= [-0.27091306]
# turn_noisy= [-9.88866309]
# fwd_noisy= [-0.51803171]
# turn_noisy= [7.36840439]
# fwd_noisy= [0.2095505]
# turn_noisy= [22.81737539]
# fwd_noisy= [0.9863744]
# turn_noisy= [6.89604155]
# fwd_noisy= [-0.15574149]
# turn_noisy= [19.80703032]
# fwd_noisy= [0.02558422]
# turn_noisy= [11.72610704]
# ...
# turn_noisy= [-4.15170878]
# fwd_noisy= [0.53917171]
# turn_noisy= [-2.51279938]
# fwd_noisy= [0.00297451]
# turn_noisy= [6.36812343]
# fwd_noisy= [-0.39239943]
# turn_noisy= [5.22212678]
# fwd_noisy= [0.85987906]
# turn_noisy= [-3.45064862]
# fwd_noisy= [0.9282777]
# turn_noisy= [5.50353721]
# fwd_noisy= [-0.47598467]
# turn_noisy= [-11.95162198]
# fwd_noisy= [0.13599917]
# turn_noisy= [6.27716983]
# fwd_noisy= [-0.13239571]
# turn_noisy= [-2.34643206]
# fwd_noisy= [0.31735144]
# turn_noisy= [4.50048726]
# fwd_noisy= [0.05998979]
# turn_noisy= [3.35566806]
# fwd_noisy= [0.408906]
# turn_noisy= [-10.21626506]
# fwd_noisy= [-0.03843339]
# turn_noisy= [13.30719565]
# fwd_noisy= [-0.10830972]
# turn_noisy= [-6.95877663]
# fwd_noisy= [0.46548183]
# turn_noisy= [1.77388278]
# fwd_noisy= [-0.42002635]
# turn_noisy= [10.1498671]
# fwd_noisy= [-0.34155642]
# turn_noisy= [9.35796611]
# fwd_noisy= [-0.0460151]
# turn_noisy= [-20.32976228]
# fwd_noisy= [-0.89125792]
# turn_noisy= [1.41057456]
# fwd_noisy= [0.11019837]
# turn_noisy= [13.55438402]
# fwd_noisy= [-0.29534765]
# turn_noisy= [-4.57166343]
# fwd_noisy= [-0.23061861]
# turn_noisy= [19.93934511]
# fwd_noisy= [-1.05508196]
# turn_noisy= [-22.69497946]
# fwd_noisy= [0.53081649]
# turn_noisy= [2.32522644]
# fwd_noisy= [-0.76015573]
# turn_noisy= [14.30548033]
# fwd_noisy= [-0.64319034]
# turn_noisy= [14.35530839]
# fwd_noisy= [0.50726042]
# turn_noisy= [-8.04868232]
# fwd_noisy= [-0.68734119]
# turn_noisy= [8.93674965]
# fwd_noisy= [-0.20087556]
# turn_noisy= [0.94741872]
# fwd_noisy= [0.26292788]
# turn_noisy= [12.51241852]
# fwd_noisy= [0.10367303]
# turn_noisy= [12.42376273]
# fwd_noisy= [1.05693011]
# turn_noisy= [2.80848817]
# fwd_noisy= [0.21587402]
# turn_noisy= [-4.92801747]
# fwd_noisy= [0.16988821]
# turn_noisy= [-8.19812993]
# fwd_noisy= [0.34739053]
# turn_noisy= [7.21635984]
# fwd_noisy= [-0.13383611]
# turn_noisy= [4.24895174]
# fwd_noisy= [0.4933411]
# turn_noisy= [3.44997884]
# fwd_noisy= [1.02527039]
# turn_noisy= [-0.39713695]
# fwd_noisy= [-0.09753194]
# turn_noisy= [6.74217466]
# fwd_noisy= [-0.01677647]
# turn_noisy= [-2.50677365]
# fwd_noisy= [0.49267572]
# turn_noisy= [-3.53521681]
# fwd_noisy= [0.01785452]
# turn_noisy= [3.35572985]
# fwd_noisy= [0.53718733]
# turn_noisy= [-6.12220192]
# fwd_noisy= [-0.41674682]
# turn_noisy= [3.38309882]
# fwd_noisy= [0.3137558]
# turn_noisy= [-4.29220698]
# fwd_noisy= [-0.99782509]
# turn_noisy= [-0.98358384]
# fwd_noisy= [-0.67095906]
# turn_noisy= [0.29866721]
# fwd_noisy= [-0.05409053]
# turn_noisy= [1.13008778]
# fwd_noisy= [-0.06271295]
# turn_noisy= [-0.49022494]
# fwd_noisy= [0.57900974]
# turn_noisy= [-5.20757643]
# fwd_noisy= [-0.73185035]
# turn_noisy= [9.98349187]
# fwd_noisy= [0.25525482]
# turn_noisy= [9.12837563]
# fwd_noisy= [-0.18434726]
# turn_noisy= [5.92582133]
# fwd_noisy= [1.17306046]
# turn_noisy= [3.83531721]
# fwd_noisy= [-0.61303732]
# turn_noisy= [4.23345775]
# fwd_noisy= [1.18472358]
# turn_noisy= [0.31559462]
# fwd_noisy= [-0.63908881]
# turn_noisy= [0.5211889]
# fwd_noisy= [-0.54492276]
# turn_noisy= [8.85623472]
# fwd_noisy= [0.04909744]
# turn_noisy= [4.21911048]
# fwd_noisy= [0.02308524]
# turn_noisy= [1.91778477]
# fwd_noisy= [-0.14413332]
# turn_noisy= [-3.81423994]
# fwd_noisy= [-0.34934308]
# turn_noisy= [1.77586695]
# fwd_noisy= [0.26044469]
# turn_noisy= [0.36735762]
# fwd_noisy= [-0.53720876]
# turn_noisy= [7.9874126]
# fwd_noisy= [0.22318107]
# turn_noisy= [7.97929703]
# fwd_noisy= [-0.35042563]
# turn_noisy= [-7.14779815]
# fwd_noisy= [0.0526374]
# turn_noisy= [16.10137849]
# fwd_noisy= [0.61564121]
# turn_noisy= [-11.31610821]
# fwd_noisy= [0.50434476]
# turn_noisy= [6.31210165]
# fwd_noisy= [0.10717665]
# turn_noisy= [2.70741276]
# fwd_noisy= [-0.77269875]
# turn_noisy= [5.34528773]
# fwd_noisy= [-0.47597395]
# turn_noisy= [11.10170244]
# fwd_noisy= [1.18321187]
# turn_noisy= [-11.96497288]
# fwd_noisy= [0.36227461]
# turn_noisy= [12.61270406]
# fwd_noisy= [0.13680643]
# turn_noisy= [4.22531964]
# fwd_noisy= [-0.65887675]
# turn_noisy= [2.31530077]
# fwd_noisy= [0.20349007]
# turn_noisy= [-1.574446]
# fwd_noisy= [-0.35982612]
# turn_noisy= [-16.98746073]
# fwd_noisy= [-0.05739292]
# turn_noisy= [-2.33910566]
# fwd_noisy= [0.10297406]
# turn_noisy= [2.91126483]
# fwd_noisy= [0.28519608]
# turn_noisy= [10.02187449]
# fwd_noisy= [0.46808633]
# turn_noisy= [2.6740547]
# fwd_noisy= [-0.23751127]
# turn_noisy= [6.03183349]
# fwd_noisy= [0.01730778]
# turn_noisy= [-21.741364]
# fwd_noisy= [0.93778925]
# turn_noisy= [10.86953467]
# fwd_noisy= [-0.22057878]
# turn_noisy= [-3.67812962]
# fwd_noisy= [0.22644113]
# turn_noisy= [11.59610053]
# fwd_noisy= [-0.58620591]
# turn_noisy= [-8.213445]
# fwd_noisy= [0.04914618]
# turn_noisy= [29.43866969]
# fwd_noisy= [-0.72335643]
# turn_noisy= [-2.69719548]
# fwd_noisy= [-0.16705098]
# turn_noisy= [8.00109905]
# fwd_noisy= [-0.33886154]
# turn_noisy= [2.07815071]
# fwd_noisy= [0.85402639]
# turn_noisy= [11.34528186]
# fwd_noisy= [0.34353545]
# turn_noisy= [14.27348102]
# fwd_noisy= [0.2811788]
# turn_noisy= [-0.25857033]
# fwd_noisy= [-0.58456872]
# turn_noisy= [9.58341401]
# fwd_noisy= [0.08094053]
# turn_noisy= [11.1564734]
# fwd_noisy= [-0.36085445]
# turn_noisy= [-17.32515775]
# fwd_noisy= [0.19744239]
# turn_noisy= [10.0278762]
# fwd_noisy= [-0.19425647]
# turn_noisy= [2.54298049]
# fwd_noisy= [0.11308302]
# turn_noisy= [-3.71610535]
# fwd_noisy= [0.18117397]
# turn_noisy= [-0.6967988]
# fwd_noisy= [-0.41182193]
# turn_noisy= [0.85145828]
# fwd_noisy= [0.5896201]
# turn_noisy= [21.20654817]
# fwd_noisy= [-0.34421002]
# turn_noisy= [5.30656721]
# fwd_noisy= [-0.17850171]
# turn_noisy= [-2.61746422]
# fwd_noisy= [0.08791843]
# turn_noisy= [10.77510032]
# fwd_noisy= [0.25847893]
# turn_noisy= [-13.37628426]
# fwd_noisy= [-0.16099176]
# turn_noisy= [26.96076715]
# fwd_noisy= [0.06751083]
# turn_noisy= [-13.23382918]
# fwd_noisy= [-0.52186094]
# turn_noisy= [6.08145845]
# fwd_noisy= [-0.06272609]
# turn_noisy= [-5.79901202]
# fwd_noisy= [0.03096773]
# turn_noisy= [21.91981898]
# fwd_noisy= [-0.61150462]
# turn_noisy= [16.34837537]
# fwd_noisy= [0.10906071]
# turn_noisy= [-2.1916773]
# fwd_noisy= [-0.21583162]
# turn_noisy= [-7.1863137]
# fwd_noisy= [0.20309732]
# turn_noisy= [29.60950767]
# fwd_noisy= [-0.56827465]
# turn_noisy= [-2.99373616]
# fwd_noisy= [0.27320235]
# turn_noisy= [-7.68054953]
# fwd_noisy= [-0.17455951]
# turn_noisy= [1.1505096]
# fwd_noisy= [0.3743287]
# turn_noisy= [-2.91068316]
# fwd_noisy= [-0.09852984]
# turn_noisy= [6.55124104]
# fwd_noisy= [-0.31116087]
# turn_noisy= [-9.39405449]
# fwd_noisy= [0.25403753]
# turn_noisy= [8.42288422]
# fwd_noisy= [0.24146721]
# turn_noisy= [8.15377027]
# fwd_noisy= [0.07427263]
# turn_noisy= [7.17164577]
# fwd_noisy= [0.43756657]
# turn_noisy= [17.16833538]
# fwd_noisy= [-0.20234154]
# turn_noisy= [14.79714507]
# fwd_noisy= [-0.11789971]
# turn_noisy= [-7.87534602]
# fwd_noisy= [-0.52166607]
# turn_noisy= [2.2045283]
# fwd_noisy= [0.22660628]
# turn_noisy= [-15.20028991]
# fwd_noisy= [-0.13847864]
# turn_noisy= [7.82822336]
# fwd_noisy= [-1.00155174]
# turn_noisy= [-23.61219425]
# fwd_noisy= [0.22217315]
# turn_noisy= [-11.65105132]
# fwd_noisy= [0.12984756]
# turn_noisy= [24.64473397]
# fwd_noisy= [0.45610287]
# turn_noisy= [13.10018797]
# fwd_noisy= [0.2341909]
# turn_noisy= [-9.63322871]
# fwd_noisy= [-0.87881003]
# turn_noisy= [3.25089023]
# fwd_noisy= [0.80148302]
# turn_noisy= [-10.19433922]
# fwd_noisy= [-0.3306712]
# turn_noisy= [6.11148694]
# fwd_noisy= [0.18750953]
# turn_noisy= [0.13347982]
# fwd_noisy= [-0.49734211]
# turn_noisy= [20.46425991]
# fwd_noisy= [-0.35818653]
# turn_noisy= [7.99408205]
# fwd_noisy= [-0.1758946]
# turn_noisy= [13.30601354]
# fwd_noisy= [-0.17424668]
# turn_noisy= [3.56954418]
# fwd_noisy= [-1.14664373]
# turn_noisy= [8.66769968]
# fwd_noisy= [-0.11161193]
# turn_noisy= [-2.6095366]
# fwd_noisy= [0.23457011]
# turn_noisy= [18.12014622]
# fwd_noisy= [-0.18676237]
# turn_noisy= [-6.62464021]
# fwd_noisy= [-0.36154139]
# turn_noisy= [-2.77432559]
# fwd_noisy= [0.37699705]
# turn_noisy= [-4.59046466]
# fwd_noisy= [-0.60365315]
# turn_noisy= [2.21397614]
# fwd_noisy= [1.21773019]
# turn_noisy= [2.41700474]
# fwd_noisy= [-0.18204089]
# turn_noisy= [-23.9759306]
# fwd_noisy= [-0.28357213]
# turn_noisy= [-2.80315982]
# fwd_noisy= [0.3865764]
# turn_noisy= [-14.55376441]
# fwd_noisy= [0.02378577]
# turn_noisy= [1.02692496]
# fwd_noisy= [0.32820188]
# turn_noisy= [13.54375598]
# fwd_noisy= [-0.09008631]
# turn_noisy= [5.54623006]
# fwd_noisy= [0.56594505]
# turn_noisy= [-18.95961663]
# fwd_noisy= [0.01938377]
# turn_noisy= [-24.83328823]
# fwd_noisy= [-0.31161259]
# turn_noisy= [-4.38614345]
# fwd_noisy= [0.08532372]
# turn_noisy= [-0.63231415]
# fwd_noisy= [-0.79711371]
# turn_noisy= [-4.39725719]
# fwd_noisy= [0.08802369]
# turn_noisy= [-3.43197438]
# fwd_noisy= [-0.1379201]
# turn_noisy= [-5.29412337]
# fwd_noisy= [0.06926712]
# turn_noisy= [-4.90215877]
# fwd_noisy= [0.11148827]
# turn_noisy= [9.20850087]
# fwd_noisy= [-0.38514874]
# turn_noisy= [1.22455812]
# fwd_noisy= [0.80340144]
# turn_noisy= [-11.75078408]
# fwd_noisy= [-0.09055681]
# turn_noisy= [21.76456978]
# fwd_noisy= [0.10737269]
# turn_noisy= [-1.87221191]
# fwd_noisy= [0.30931598]
# turn_noisy= [-6.65363524]
# fwd_noisy= [0.54702692]
# turn_noisy= [-6.73835766]
# fwd_noisy= [-0.11404696]
# turn_noisy= [0.27225755]
# fwd_noisy= [0.24743955]
# turn_noisy= [4.51454525]
# fwd_noisy= [-0.62829898]
# turn_noisy= [-6.45585712]
# fwd_noisy= [0.15438682]
# turn_noisy= [1.64968089]
# fwd_noisy= [-0.52770399]
# turn_noisy= [16.44441691]
# fwd_noisy= [-1.21197632]
# turn_noisy= [5.03654806]
# fwd_noisy= [0.43231964]
# turn_noisy= [-3.38578158]
# fwd_noisy= [0.37677571]
# turn_noisy= [-0.65814107]
# fwd_noisy= [0.26243878]
# turn_noisy= [-6.50396459]
# fwd_noisy= [0.32800422]
# turn_noisy= [6.66030741]
# fwd_noisy= [-0.3941968]
# turn_noisy= [-1.55913572]
# fwd_noisy= [-0.01472901]
# turn_noisy= [10.5342603]
# fwd_noisy= [-0.25259311]
# turn_noisy= [-19.04585145]
# fwd_noisy= [-0.42579907]
# turn_noisy= [-5.41907984]
# fwd_noisy= [-0.28936818]
# turn_noisy= [-5.03448302]
# fwd_noisy= [0.94630495]
# turn_noisy= [8.39590419]
# fwd_noisy= [-0.26865059]
# turn_noisy= [1.10200399]
# fwd_noisy= [0.09260262]
# turn_noisy= [3.21320009]
# fwd_noisy= [-0.37205466]
# turn_noisy= [-7.29039937]
# fwd_noisy= [0.29739736]
# turn_noisy= [-1.3261875]
# fwd_noisy= [0.23071945]
# turn_noisy= [12.48116025]
# fwd_noisy= [0.58798217]
# turn_noisy= [12.70757573]
# fwd_noisy= [0.02238373]
# turn_noisy= [15.2712837]
# fwd_noisy= [1.35674389]
# turn_noisy= [5.56669942]
# fwd_noisy= [-0.28611426]
# turn_noisy= [-3.07573306]
# fwd_noisy= [-0.2682491]
# turn_noisy= [3.65356854]
# fwd_noisy= [0.30809577]
# turn_noisy= [-11.24152543]
# fwd_noisy= [1.13187739]
# turn_noisy= [-0.57735752]
# fwd_noisy= [0.49683256]
# turn_noisy= [21.46680381]
# fwd_noisy= [-0.11048172]
# turn_noisy= [-13.766661]
# fwd_noisy= [-0.20689798]
# turn_noisy= [-10.01508174]
# fwd_noisy= [-0.22907604]
# turn_noisy= [-15.52250767]
# fwd_noisy= [0.88826205]
# turn_noisy= [-1.87394427]
# fwd_noisy= [0.17691729]
# turn_noisy= [-3.44913149]
# fwd_noisy= [-0.4654713]
# turn_noisy= [-19.37936845]
# fwd_noisy= [-0.15563983]
# turn_noisy= [-4.89484868]
# fwd_noisy= [-0.93614788]
# turn_noisy= [2.65114872]
# fwd_noisy= [-0.54807177]
# turn_noisy= [13.57156695]
# fwd_noisy= [0.02335484]
# turn_noisy= [5.9069795]
# fwd_noisy= [-0.34455562]
# turn_noisy= [-6.01023315]
# fwd_noisy= [-0.14968147]
# turn_noisy= [11.46523582]
# fwd_noisy= [0.16578743]
# turn_noisy= [-0.60393622]
# fwd_noisy= [0.05333418]
# turn_noisy= [-2.47787153]
# fwd_noisy= [0.29388099]
# turn_noisy= [-4.15940266]
# fwd_noisy= [0.61083455]
# turn_noisy= [11.48276582]
# fwd_noisy= [0.25117541]
# turn_noisy= [-16.932694]
# fwd_noisy= [-0.45878568]
# turn_noisy= [20.39113652]
# fwd_noisy= [-0.73093096]
# turn_noisy= [-10.77590479]
# fwd_noisy= [0.17872099]
# turn_noisy= [4.54114539]
# fwd_noisy= [-0.39154113]
# turn_noisy= [21.69359188]
# fwd_noisy= [-0.34060843]
# turn_noisy= [-6.52422645]
# fwd_noisy= [0.46227976]
# turn_noisy= [-2.26742771]
# fwd_noisy= [-0.20389838]
# turn_noisy= [9.88139365]
# fwd_noisy= [-0.57077369]
# turn_noisy= [13.22946835]
# fwd_noisy= [-0.16994337]
# turn_noisy= [3.9059998]
# fwd_noisy= [0.39747618]
# turn_noisy= [0.02461939]
# fwd_noisy= [-0.49518655]
# turn_noisy= [-11.81694773]
# fwd_noisy= [0.24026276]
# turn_noisy= [-3.00433378]
# fwd_noisy= [0.09841777]
# turn_noisy= [10.19095461]
# fwd_noisy= [-0.08497266]
# turn_noisy= [8.63732111]
# fwd_noisy= [0.32808307]
# turn_noisy= [-5.43818569]
# fwd_noisy= [0.40604377]
# turn_noisy= [5.44604092]
# fwd_noisy= [-0.39938815]
# turn_noisy= [0.37283089]
# fwd_noisy= [0.18231514]
# turn_noisy= [-13.14291301]
# fwd_noisy= [0.34265035]
# turn_noisy= [-3.21799274]
# fwd_noisy= [0.14188124]
# turn_noisy= [8.43020598]
# fwd_noisy= [-0.32592178]
# turn_noisy= [-1.26008801]
# fwd_noisy= [-1.51803032]
# turn_noisy= [3.55390777]
# fwd_noisy= [-0.16683669]
# turn_noisy= [-6.81105726]
# fwd_noisy= [0.00185025]
# turn_noisy= [11.1777229]
# fwd_noisy= [-0.136203]
# turn_noisy= [-25.83083259]
# fwd_noisy= [0.05030025]
# turn_noisy= [8.59948647]
# fwd_noisy= [-0.36102071]
# turn_noisy= [1.3375868]
# fwd_noisy= [-0.27177284]
# turn_noisy= [7.8300481]
# fwd_noisy= [0.09797221]
# turn_noisy= [13.13806614]
# fwd_noisy= [-0.12842497]
# turn_noisy= [-4.88311541]
# fwd_noisy= [-0.22199557]
# turn_noisy= [8.71470412]
# fwd_noisy= [-0.55240176]
# turn_noisy= [7.3676595]
# fwd_noisy= [1.0225065]
# turn_noisy= [9.15840873]
# fwd_noisy= [-0.43501122]
# turn_noisy= [7.31734573]
# fwd_noisy= [0.15489351]
# turn_noisy= [3.54711477]
# fwd_noisy= [0.24438936]
# turn_noisy= [-3.5530809]
# fwd_noisy= [-1.01438304]
# turn_noisy= [-0.04258258]
# fwd_noisy= [-0.41833998]
# turn_noisy= [-6.31489678]
# fwd_noisy= [-0.60264757]
# turn_noisy= [15.66564986]
# fwd_noisy= [-0.58598607]
# turn_noisy= [3.39928138]
# fwd_noisy= [-0.51128943]
# turn_noisy= [3.65674038]
# fwd_noisy= [-0.315249]
# turn_noisy= [7.21754873]
# fwd_noisy= [0.17003098]
# turn_noisy= [16.78142959]
# fwd_noisy= [0.08031283]
# turn_noisy= [-5.50370241]
# fwd_noisy= [0.16678068]
# turn_noisy= [-11.50440224]
# fwd_noisy= [-0.03679005]
# turn_noisy= [3.15612998]
# fwd_noisy= [0.44932972]
# turn_noisy= [14.56554935]
# fwd_noisy= [-0.81463148]
# turn_noisy= [-9.48587497]
# fwd_noisy= [-0.95488414]
# turn_noisy= [0.64950559]
# fwd_noisy= [0.29693569]
# turn_noisy= [3.16093658]
# fwd_noisy= [-0.07954935]
# turn_noisy= [-6.43059802]
# fwd_noisy= [-0.26089074]
# turn_noisy= [11.45784908]
# fwd_noisy= [0.33993916]
# turn_noisy= [12.38730195]
# fwd_noisy= [0.68398418]
# turn_noisy= [3.17639862]
# fwd_noisy= [-0.2314222]
# turn_noisy= [-1.7750106]
# fwd_noisy= [-0.28384921]
# turn_noisy= [-7.28227545]
# fwd_noisy= [-0.00763491]
# turn_noisy= [5.59800361]
# fwd_noisy= [-0.83172467]
# turn_noisy= [-7.24097912]
# fwd_noisy= [0.40414559]
# turn_noisy= [-14.78277608]
# fwd_noisy= [-0.66987151]
# turn_noisy= [15.1661349]
# fwd_noisy= [0.71266335]
# turn_noisy= [0.52346438]
# fwd_noisy= [1.16492094]
# turn_noisy= [15.77651751]
# fwd_noisy= [1.10286564]
# turn_noisy= [8.39531402]
# fwd_noisy= [-0.2696157]
# turn_noisy= [-0.18807992]
# fwd_noisy= [-0.99786]
# turn_noisy= [-4.37957975]
# fwd_noisy= [0.42882736]
# turn_noisy= [27.68976468]
# fwd_noisy= [-0.28271536]
# turn_noisy= [8.6715704]
# fwd_noisy= [-0.08669368]
# turn_noisy= [0.29993096]
# fwd_noisy= [1.04554374]
# turn_noisy= [-1.77058563]
# fwd_noisy= [-0.92077898]
# turn_noisy= [2.09633602]
# fwd_noisy= [0.33149335]
# turn_noisy= [-3.61571725]
# fwd_noisy= [0.67949951]
# turn_noisy= [0.00037734]
# fwd_noisy= [-0.44350441]
# turn_noisy= [-4.4346771]
# fwd_noisy= [0.24355881]
# turn_noisy= [-12.40586249]
# fwd_noisy= [0.93784842]
# turn_noisy= [8.81037417]
# fwd_noisy= [0.42078975]
# turn_noisy= [-13.32113951]
# fwd_noisy= [0.25544691]
# turn_noisy= [4.99043562]
# fwd_noisy= [-0.13795249]
# turn_noisy= [-8.14946322]
# fwd_noisy= [-0.0553935]
# turn_noisy= [0.9568981]
# fwd_noisy= [-0.13945427]
# turn_noisy= [-1.15955366]
# fwd_noisy= [0.02404485]
# turn_noisy= [0.87551297]
# fwd_noisy= [-0.18890146]
# turn_noisy= [12.4599501]
# fwd_noisy= [0.3018926]
# turn_noisy= [7.15912848]
# fwd_noisy= [0.42015456]
# turn_noisy= [-16.93267097]
# fwd_noisy= [0.06049511]
# turn_noisy= [-0.12399378]
# fwd_noisy= [-0.57116183]
# turn_noisy= [11.45560913]
# fwd_noisy= [0.44557385]
# turn_noisy= [15.95319375]
# fwd_noisy= [-0.07961554]
# turn_noisy= [-14.86016805]
# fwd_noisy= [-0.12754732]
# turn_noisy= [16.5407618]
# fwd_noisy= [-0.51655645]
# turn_noisy= [4.67517262]
# fwd_noisy= [-0.09887907]
# turn_noisy= [0.18815455]
# fwd_noisy= [-0.45220303]
# turn_noisy= [1.06606368]
# fwd_noisy= [0.00689448]
# turn_noisy= [3.96103435]
# fwd_noisy= [0.45863823]
# turn_noisy= [-5.9692243]
# fwd_noisy= [-0.73617409]
# turn_noisy= [16.06811585]
# fwd_noisy= [-0.0086276]
# turn_noisy= [5.15528563]
# fwd_noisy= [0.06766873]
# turn_noisy= [-1.56075867]
# fwd_noisy= [0.24663098]
# turn_noisy= [13.49070318]
# fwd_noisy= [0.18018884]
# turn_noisy= [-6.0671228]
# fwd_noisy= [0.58223404]
# turn_noisy= [-2.13105999]
